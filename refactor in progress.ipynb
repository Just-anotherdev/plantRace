# %%
import random
import pygame
import numpy as np
from PIL import Image
import time
import base64
import re


class Engine:
    def __init__(self):
        pygame.init()  # initialize pygame
        pygame.font.init()  # initialize fonts
        self.basefont = pygame.font.SysFont("Comic Sans MS", 30)  # finish initializing font
        self.stopwatch = stopwatch()
        self.stopwatch.update()
        self.scoreboard = scoreboard()
        self.init_groups()
        self.init_screen()
        self.poodissapear = 1
        self.food = 0
        self.score = 0
        self.clock = pygame.time.Clock()
        self.resetiter = 0
        self.animationtimer = 0
        self.growtimer = 0
        self.winner = 0
        self.starttime = time.time()
        self.showcontrols = 1
        self.winscore = 0
        self.haspooped = 0
        self.mode = 0
        self.itt = interactivetextbox()
        self.stringbuffer = []

    def init_score(self):
        self.score = 0
        self.winscore = 0
        self.mapscore = 0
        for sprite in self.tileset:
            if sprite.tilename == "plant1stage3wet":
                self.mapscore = self.mapscore + 1
        for sprite in self.tileset:
            if (
                sprite.tilename == "plant1stage1wet"
                or sprite.tilename == "plant1stage2wet"
                or sprite.tilename == "dirtwet"
            ):
                self.winscore = self.winscore + 1

    def test_win(self):
        if self.score >= self.winscore:
            self.winner = 1
            self.scoreboard.write(self.stopwatch.elapsedsec)
        if self.winner == 1:
            for sprite in self.poopobj:
                sprite.image = pygame.image.load("Assets/sprites/goldpoop.png")
            for sprite in self.fishobj:
                sprite.kill()
            self.food = 5000
            self.poodissapear = 0
            self.mode = 5
    def init_screen(self):
        self.windowh = 640
        self.windoww = 960
        self.screen = pygame.display.set_mode((self.windoww, self.windowh))

    def init_groups(self):
        self.poopobj = pygame.sprite.Group()  # all poops
        self.fishobj = pygame.sprite.Group()  # all fish
        self.tileset = pygame.sprite.Group()  # all tiles
        self.allvisible = pygame.sprite.Group()  # all visible sprites
        self.watertiles = pygame.sprite.Group()  # all watertiles
        self.toanimate = pygame.sprite.Group()

    def render_screen(self):
        
        if self.mode == 0:
            splashscreen = pygame.image.load(f"{self.splashprefix}startscreen.png")
            self.screen.blit(splashscreen, (0,0))
        elif self.mode == 1:
            splashscreen = pygame.image.load(f"{self.splashprefix}entername.png")
            self.screen.blit(splashscreen, (0,0))
            self.render_hud()
        elif self.mode == 2:
            splashscreen = pygame.image.load(f"{self.splashprefix}controls.png")
            self.screen.blit(splashscreen,(0,0))
        elif self.mode == 3:
            
            #game running
            for sprite in self.allvisible:
                
                self.screen.blit(
                    sprite.image,
                    (sprite.rect.x - cameraobj.rect.x, sprite.rect.y - cameraobj.rect.y),
                )
                
            self.render_hud()
        elif self.mode == 4:
            splashscreen = pygame.image.load(f"{self.splashprefix}pause.png")
            self.screen.blit(splashscreen,(0,0))
            pass
        elif self.mode == 5:
            splashscreen = pygame.image.load(f"{self.splashprefix}winscreen.png")
            self.screen.blit(splashscreen, (0,0))
            self.render_hud()
            #game won
            pass
        
        pygame.display.flip()
        
        
    def render_hud(self):
        if self.mode == 1:
            self.itt.render()
        elif self.mode == 3:
            if self.showcontrols == 1:
                controlmessage = self.basefont.render("use the arrow keys or wasd to move", False, (255, 255, 255))
                self.screen.blit(controlmessage, ((self.windoww / 2) - 200, (self.windowh / 2) - 200))
            elif self.showcontrols == 0 and self.food < 2 and self.score < self.winscore:
                hungermes = self.basefont.render("you feel hungry", False, (255, 255, 255))
                self.screen.blit(hungermes, ((self.windoww / 2) - 100, (self.windowh / 2) - 200))
            elif self.showcontrols == 0 and self.food == 100 and self.score < self.winscore:
                fullmesg = self.basefont.render("you feel full", False, (255, 255, 255))
                self.screen.blit(fullmesg, ((self.windoww / 2) - 80, (self.windowh / 2) - 200))
            elif self.showcontrols == 0 and self.food > 2 and self.haspooped == 0:
                poomesg = self.basefont.render("use spacebar to poop. plants need poop to grow", False, (255, 255, 255))
                self.screen.blit(poomesg, ((self.windoww / 2) - 250, (self.windowh / 2) - 200))
            elif self.showcontrols == 0 and self.haspooped == 1:
                scoremesg = self.basefont.render(f"SCORE: {self.score}  /  {self.winscore}", False, (255, 255, 255))
                self.screen.blit(scoremesg, ((self.windoww / 2) - 58, (self.windowh / 10)))
            stopwatchmesg = self.basefont.render(self.stopwatch.stopwatchmesg, False, (255, 255, 255))
            self.screen.blit(stopwatchmesg, (50, ((self.windowh / 10) * 9)))
        elif self.mode == 5:
            if self.winner == 1:
                winmessage = self.basefont.render("you win! thanks for playing my tech demo!", False, (255, 255, 255))
                self.screen.blit(winmessage, ((self.windoww / 2) - 180, self.windowh / 2 - 220))
                self.scoreboard.build()
                
                if len(self.scoreboard.top10) >= 1:
                    self.screen.blit(self.scoreboard.mesg, (((self.windoww /2) - 50), self.windowh / 2 - 180))
                    self.screen.blit(self.scoreboard.first, (((self.windoww / 2) - 145), self.windowh / 2 - 160))
                if len(self.scoreboard.top10) >= 2:
                    self.screen.blit(self.scoreboard.second, (((self.windoww / 2) - 145), self.windowh / 2 - 140))
                if len(self.scoreboard.top10) >= 3:
                    self.screen.blit(self.scoreboard.third, (((self.windoww / 2) - 145), self.windowh / 2 - 120))
                if len(self.scoreboard.top10) >= 4:
                    self.screen.blit(self.scoreboard.fourth, (((self.windoww / 2) - 145), self.windowh / 2 - 100))
                if len(self.scoreboard.top10) >= 5:
                    self.screen.blit(self.scoreboard.fifth, (((self.windoww / 2) - 145), self.windowh / 2 - 80))
                if len(self.scoreboard.top10) >= 6:
                    self.screen.blit(self.scoreboard.sixth, (((self.windoww / 2) - 145), self.windowh / 2 - 60))
                if len(self.scoreboard.top10) >= 7:
                    self.screen.blit(self.scoreboard.seventh, (((self.windoww / 2) - 145), self.windowh / 2 - 40))
                if len(self.scoreboard.top10) >= 8:
                    self.screen.blit(self.scoreboard.eigth, (((self.windoww / 2) - 145), self.windowh / 2 - 20))
                if len(self.scoreboard.top10) >= 9:
                    self.screen.blit(self.scoreboard.ninth, (((self.windoww / 2) - 145), self.windowh / 2))
                if len(self.scoreboard.top10) >= 10:
                    self.screen.blit(self.scoreboard.tenth, ((((self.windoww / 2) - 145), ((self.windowh / 2) + 20))))
            

    def update_logic(self):
        
        if self.mode == 0:
            #title screen
            pass
        elif self.mode == 1:
            #enter name
            self.itt.update()
            pass
        elif self.mode == 2:
            #show controls
            pass
        elif self.mode == 3:
            
            self.normalize_velocity()
            
            self.update_fish()
            
            mycat.update()
            
            self.poopobj.update()
            
            self.animate_all()
            
            cameraobj.update()
            
            self.lock_in_bounds()
            
            self.calculate_score()
            
            self.test_win()
            
            self.grow_plants()
            
            if self.winner == 0:
                self.stopwatch.update()
                
        elif self.mode == 4:
            #
            #
            self.stopwatch.update()
            #
            pass
        elif self.mode == 5:
            #won
            pass
        
    def animate_all(self):
        self.animationtimer = self.animationtimer + 1
        if self.animationtimer > 10:
            self.animationtimer = 0
            for sprite in self.toanimate:
                sprite.animate()

    def test_keys(self):
        
        if self.mode == 0:
            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_SPACE:
                        self.mode = 1
                if event.type == pygame.QUIT:
                    pygame.quit()
                    quit()
        elif self.mode == 1:
            #enter name
            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_RETURN:
                        self.playername = "".join(self.stringbuffer)
                        self.stringbuffer = []
                        self.mode = 2
                    elif event.key == pygame.K_BACKSPACE:
                        if len(self.stringbuffer) >= 1:
                            self.stringbuffer.pop()
                    else:
                        self.stringbuffer.append(event.unicode)
                if event.type == pygame.QUIT:
                    pygame.quit()
                    quit()
        elif self.mode == 2:
            #show controls
            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_SPACE:
                        self.stopwatch.reset()
                        self.mode = 3
                        
                if event.type == pygame.QUIT:
                    pygame.quit()
                    quit()
        elif self.mode == 3:
            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_u:
                        mycat.catcolor = 0
                        
                    if event.key == pygame.K_i:
                        mycat.catcolor = 1
                    if event.key == pygame.K_o:
                        mycat.catcolor = 2
                    if event.key == pygame.K_q:
                        self.winner = 1
                        self.scoreboard.write(self.stopwatch.elapsedsec)
                    if event.key == pygame.K_LEFT or event.key == pygame.K_a:
                        mycat.xv = -10
                        self.showcontrols = 0
                    elif event.key == pygame.K_RIGHT or event.key == pygame.K_d:
                        mycat.xv = 10
                        self.showcontrols = 0
                    elif event.key == pygame.K_UP or event.key == pygame.K_w:
                        mycat.yv = -10
                        self.showcontrols = 0
                    elif event.key == pygame.K_DOWN or event.key == pygame.K_s:
                        mycat.yv = 10
                        self.showcontrols = 0
                    if event.key == 27:  # escape
                        self.mode = 4
                        self.stopwatch.pause()
                        
                    elif event.key == 32:  # spacebar
                        if self.food > 0:
                            self.food = self.food - 1
                            if len(self.poopobj) < 10:
                                Poop(mycat.rect.left, mycat.rect.top)
                            else:
                                j = 0
                                tempi = 0
                                while tempi < 10:
                                    tempi = tempi + 1
                                    for e in self.poopobj:
                                        j = j + 1
                                        if j == 1:
                                            if self.poodissapear == 1:
                                                e.kill()
                                            Poop(mycat.rect.left, mycat.rect.top)
                if event.type == pygame.KEYUP:
                    if event.key == pygame.K_LEFT or event.key == pygame.K_a:
                        mycat.resetx = 1
                    elif event.key == pygame.K_RIGHT or event.key == pygame.K_d:
                        mycat.resetx = 1
                    elif event.key == pygame.K_UP or event.key == pygame.K_w:
                        mycat.resety = 1
                    elif event.key == pygame.K_DOWN or event.key == pygame.K_s:
                        mycat.resety = 1
                if event.type == pygame.QUIT:
                    pygame.quit()
                    quit()
        if self.mode == 4:
                for event in pygame.event.get():
                    if event.type == pygame.KEYDOWN:
                        if event.key == 27:
                            self.mode = 3
                            self.stopwatch.unpause()
                    if event.type == pygame.QUIT:
                        pygame.quit()
                        quit()
        if self.mode == 5:
                for event in pygame.event.get():
                    if event.type == pygame.QUIT:
                        pygame.quit()
                        quit()

    def update_fish(self):
        if len(self.fishobj) < len(self.watertiles) * 2:
            for sprite in self.tileset:
                sprite.populate_fish()
        for e in self.fishobj:
            if e.rect.colliderect(mycat.rect) == True:
                if self.food < 100:
                    self.food = self.food + 1
                    e.kill()

    def calculate_score(self):
        self.score = 0
        for sprite in self.tileset:
            if sprite.tilename == "plant1stage3wet":
                self.score = self.score + 1
        self.score = self.score - self.mapscore

    def normalize_velocity(self):
        if mycat.xv > 10:
            mycat.xv = 10
        if mycat.yv > 10:
            mycat.yv = 10
        if mycat.xv < -10:
            mycat.xv = -10
        if mycat.yv < -10:
            mycat.yv = -10
        self.resetiter = self.resetiter + 1
        if self.resetiter > 5:
            self.resetiter = 0
            if mycat.resetx == 1:
                mycat.xv = 0
                mycat.resetx = 0
            if mycat.resety == 1:
                mycat.yv = 0
                mycat.resety = 0
            mycat.resetx = 0
            mycat.resety = 0

    def grow_plants(self):
        self.growtimer = self.growtimer + 1
        if self.growtimer > 60:
            self.growtimer = 0
            for sprite in self.tileset:
                sprite.grow()

    def lock_in_bounds(self):
        mycat.rect.clamp_ip(self.bgframe.rect)
        cameraobj.rect.clamp_ip(self.bgframe.rect)


class Camera(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.rect = pygame.Rect(0, 0, myengine.windoww, myengine.windowh)
        self.update()

    def update(self):
        self.rect.centerx, self.rect.centery = mycat.rect.centerx, mycat.rect.centery


class interactivetextbox(pygame.sprite.Sprite):
    def __init__(self):
        pass
    def render(self):
        myengine.screen.blit(self.image,self.rect)
    def update(self):
        self.image = myengine.basefont.render("".join(myengine.stringbuffer), False , (255, 255, 255))
        self.rect = self.image.get_rect()
        self.rect.center = (myengine.windoww / 2, myengine.windowh / 2)
        pass

class Background(Engine):
    def __init__(self):
        super().__init__()
        self.tileprefix = "Assets/tiles/"  # prefix for tile filenames
        self.mapprefix = "Assets/maps/"  # prefix for input map filenames
        self.splashprefix = "Assets/splashscreens/"
        self.generate_bg()

    def init_bg_frame(self):
        self.bgframe = Bgframe()

    def init_tiles(self, tilename=("finishinit"), x=0, y=0):
        # this function initializes the tileset with the proper states based on tilename
        assert (
            type(tilename) is str
        ), "check input to inittiles tilename must be a string"
        assert (
            type(x) is int and type(y) is int
        ), "check input to inittiles x and y must be positive ints"
        assert (
            x >= 0 and y >= 0
        ), "check input to inittiles x and y must be positive ints"
        if tilename == "catbeddry":
            Tile("catbeddry", f"{self.tileprefix}catbeddry.png", x, y, self)
        elif tilename == "catbedwet":
            Tile("catbedwet", f"{self.tileprefix}catbedwet.png", x, y, self)
        elif tilename == "dirtdry":
            Tile("dirtdry", f"{self.tileprefix}dirtdry.png", x, y, self)
        elif tilename == "dirtuntilled":
            Tile("dirtuntilled", f"{self.tileprefix}dirtuntilled.png", x, y, self)
        elif tilename == "dirtwet":
            Tile("dirtwet", f"{self.tileprefix}dirtwet.png", x, y, self)
        elif tilename == "grass1":
            Tile("grass1", f"{self.tileprefix}grass1.png", x, y, self)
        elif tilename == "plant1stage1dry":
            Tile("plant1stage1dry", f"{self.tileprefix}plant1stage1dry.png", x, y, self)
        elif tilename == "plant1stage1wet":
            Tile("plant1stage1wet", f"{self.tileprefix}plant1stage1wet.png", x, y, self)
        elif tilename == "plant1stage2dry":
            Tile("plant1stage2dry", f"{self.tileprefix}plant1stage2dry.png", x, y, self)
        elif tilename == "plant1stage2wet":
            Tile("plant1stage2wet", f"{self.tileprefix}plant1stage2wet.png", x, y, self)
        elif tilename == "plant1stage3dry":
            Tile("plant1stage3dry", f"{self.tileprefix}plant1stage3dry.png", x, y, self)
        elif tilename == "plant1stage3wet":
            Tile("plant1stage3wet", f"{self.tileprefix}plant1stage3wet.png", x, y, self)
        elif tilename == "water":
            Tile("water", f"{self.tileprefix}water.png", x, y, self)
        else:
            pass

    def map_to_tiles(self, mapname):
        mappath = f"{self.mapprefix}{mapname}.png"
        conversiondict = {  # dictionary of tuples of rgb values as keys for tile names
            (np.uint8(229), np.uint8(45), np.uint8(255)): "catbeddry",
            (np.uint8(183), np.uint8(4), np.uint8(134)): "catbedwet",
            (np.uint8(241), np.uint8(240), np.uint8(92)): "dirtdry",
            (np.uint8(202), np.uint8(195), np.uint8(67)): "dirtuntilled",
            (np.uint8(74), np.uint8(41), np.uint8(0)): "dirtwet",
            (np.uint8(32), np.uint8(254), np.uint8(0)): "grass1",
            (np.uint8(224), np.uint8(166), np.uint8(41)): "plant1stage1dry",
            (np.uint8(227), np.uint8(243), np.uint8(0)): "plant1stage1wet",
            (np.uint8(255), np.uint8(198), np.uint8(45)): "plant1stage2dry",
            (np.uint8(212), np.uint8(255), np.uint8(0)): "plant1stage2wet",
            (np.uint8(255), np.uint8(174), np.uint8(0)): "plant1stage3dry",
            (np.uint8(255), np.uint8(253), np.uint8(0)): "plant1stage3wet",
            (np.uint8(0), np.uint8(36), np.uint8(254)): "water",
        }
        img = Image.open(mappath)  # import image as a pillow image
        img = img.convert("RGB")  # drop alpha
        img = np.asarray(img)  # import picture as numpy array
        inputw = img.shape[1]  # set inputw to the width of the input image
        inputh = img.shape[0]  # set inputh to the height of the input image
        p = 0
        tiles = []  # initialize
        temparray = []  # initialize a temporary array to pop from
        rgbvalues = []  # flat array of tuples representing rgb values
        for (
            m
        ) in (
            img
        ):  # loop through the 3d numpy array to extract an 1d array of tuples of rgb values
            for n in m:
                for o in n:
                    if p < 3:
                        p = p + 1
                        temparray.append(o)
                    else:
                        p = 1
                        rgbvalues.append(tuple(temparray))
                        temparray = []
                        temparray.append(o)
        rgbvalues.append(tuple(temparray))
        temparray = []
        for x in rgbvalues:  # convert the array to an array of tile file names
            tiles.append(conversiondict[x])
        return (tiles, inputh, inputw)

    def tiles_to_full_map(self, listoftiles, numofrows, numofcols):
        assert len(listoftiles) + 1 != int(numofrows) * int(
            numofcols
        ), "the list passed to tilestofullmap would not generate a valid map"
        tilewidth = 200  # the width in pixels of the tiles
        tileheight = 200  # the width in pixels of the tiles
        j = 1
        witer = 0
        hiter = 0
        bgwidth = numofcols * tilewidth
        bgheight = numofrows * tileheight
        iterlist = [0] * len(listoftiles)
        for e in iterlist:
            if j < numofcols:
                self.init_tiles(listoftiles.pop(0), witer, hiter)
                witer = witer + tilewidth
            else:
                self.init_tiles(listoftiles.pop(0), witer, hiter)
                witer = 0
                j = 0
                hiter = hiter + tileheight
            j = j + 1
        self.bgwidth, self.bgheight = bgwidth, bgheight

    def generate_bg(self):
        catchreturn1 = self.map_to_tiles("microdemo")
        self.tiles_to_full_map(catchreturn1[0], catchreturn1[1], catchreturn1[2])


class Tile(pygame.sprite.Sprite, Background):
    def __init__(self, tilename, image_file, posx, posy, engine):
        assert type(tilename) is str, "tilename must be a string"
        assert (
            type(posx) is int and type(posy) is int and posx >= 0 and posy >= 0
        ), "posx and posy must be positivve ints"
        self.tilename = tilename
        pygame.sprite.Sprite.__init__(self)  # call Sprite initializer
        self.image = pygame.image.load(image_file)  # load the tile image by name
        self.image = self.image.convert()
        self.rect = self.image.get_rect()  # prebaked rect from image
        self.rect.left, self.rect.top = (
            posx,
            posy,
        )  # takes in arguments to set position of rect
        tilename = tilename  # defines tilename
        engine.allvisible.add(self)  # adds to visible objects
        engine.tileset.add(self)
        if self.tilename == "water":  # adds to the group of water tiles if it is one
            engine.watertiles.add(self)

    def grow(self):
        # grows all plants that are wet and have [poop on them]
        if self.tilename == "plant1stage1wet":
            if pygame.sprite.spritecollideany(self, myengine.poopobj) is not None:
                self.tilename = "plant1stage2wet"
                self.image = pygame.image.load(
                    f"{myengine.tileprefix}plant1stage2wet.png"
                )
                self.image = self.image.convert()
                pooptokill = pygame.sprite.spritecollideany(self, myengine.poopobj)
                pooptokill.used = 1
        elif self.tilename == "plant1stage2wet":
            if pygame.sprite.spritecollideany(self, myengine.poopobj) is not None:
                self.tilename = "plant1stage3wet"
                self.image = pygame.image.load(
                    f"{myengine.tileprefix}plant1stage3wet.png"
                )
                self.image = self.image.convert()
                pooptokill = pygame.sprite.spritecollideany(self, myengine.poopobj)
                pooptokill.used = 1
        elif self.tilename == "dirtwet":
            if pygame.sprite.spritecollideany(self, myengine.poopobj) is not None:
                self.tilename = "plant1stage1wet"
                self.image = pygame.image.load(
                    f"{myengine.tileprefix}plant1stage1wet.png"
                )
                self.image = self.image.convert()
                pooptokill = pygame.sprite.spritecollideany(self, myengine.poopobj)
                pooptokill.used = 1

    def populate_fish(self):
        if self.tilename == "water":
            fish(
                random.randrange(
                    self.rect.left, (self.rect.left + self.rect.width) - 32
                ),
                random.randrange(self.rect.top, (self.rect.top + self.rect.width) - 32),
            )


class Bgframe(pygame.sprite.Sprite):
    # makes a rect around the background for collision detection
    def __init__(self):
        assert (
            type(myengine.bgwidth) is int and type(myengine.bgheight) is int
        ), "Bgframe requires bgheight and bgwidth to be non zero positive ints"
        assert (
            myengine.bgwidth > 0 and myengine.bgheight > 0
        ), "Bgframe requires bgheight and bgwidth to be non zero positive ints"
        pygame.sprite.Sprite.__init__(self)
        self.rect = pygame.Rect(0, 0, myengine.bgwidth, myengine.bgheight)

class scoreboard:
    def __init__(self):
        with open("Assets/saves/sb.scoreboard", "r") as scoreboard:
            scoreboard_b64_list = scoreboard.readlines()
            unsortedScoreboard = []
            for i in scoreboard_b64_list:
                unsortedScoreboard.append(base64.standard_b64decode(i).decode())
            self.unsortedscoreboard = unsortedScoreboard
            self.sortedscoreboard = sorted(
                unsortedScoreboard, key=lambda test_string: list(map(int, re.findall(r"\d+", test_string)))[0]
            )
            self.top10 = []
            i = 0
            for score in self.sortedscoreboard:
                if i <= 9:
                    self.top10.append(score)
                    i = i + 1

    def write(self, timelapsed):
        winning_stopwatch = f"{myengine.playername}  {myengine.stopwatch.elapsedsec:.2f} seconds"
        winning_stopwatch = winning_stopwatch.encode("utf-8")
        with open("Assets/saves/sb.scoreboard", "a") as scoreboard:
            b64winning_stopwatch = base64.standard_b64encode(winning_stopwatch)
            scoreboard.write(b64winning_stopwatch.decode())
            scoreboard.write("\n")
        with open("Assets/saves/sb.scoreboard", "r") as scoreboard:
            scoreboard_b64_list = scoreboard.readlines()
            unsortedScoreboard = []
            for i in scoreboard_b64_list:
                unsortedScoreboard.append(base64.standard_b64decode(i).decode())
            self.unsortedscoreboard = unsortedScoreboard
            self.sortedscoreboard = sorted(
                unsortedScoreboard, key=lambda test_string: list(map(int, re.findall(r"\d+", test_string)))[0]
            )
            self.top10 = []
            i = 0
            for score in self.sortedscoreboard:
                if i <= 9:
                    self.top10.append(score)
                    i = i + 1
                    
    def build(self):
        if len(self.top10) >= 10:
            self.tenth = myengine.basefont.render(f"10). {self.top10[9]}", False, (255, 255, 255))
        if len(self.top10) >= 9:
            self.ninth = myengine.basefont.render(f"9). {self.top10[8]}", False, (255, 255, 255))
        if len(self.top10) >= 8:
            self.eigth = myengine.basefont.render(f"8). {self.top10[7]}", False, (255, 255, 255))
        if len(self.top10) >= 7:
            self.seventh = myengine.basefont.render(f"7). {self.top10[6]}", False, (255, 255, 255))
        if len(self.top10) >= 6:
            self.sixth = myengine.basefont.render(f"6). {self.top10[5]}", False, (255, 255, 255))
        if len(self.top10) >= 5:
            self.fifth = myengine.basefont.render(f"5). {self.top10[4]}", False, (255, 255, 255))
        if len(self.top10) >= 4:
            self.fourth = myengine.basefont.render(f"4). {self.top10[3]}", False, (255, 255, 255))
        if len(self.top10) >= 3:
            self.third = myengine.basefont.render(f"3). {self.top10[2]}", False, (255, 255, 255))
        if len(self.top10) >= 2:
            self.second = myengine.basefont.render(f"2). {self.top10[1]}", False, (255, 255, 255))
        if len(self.top10) >= 1:
            self.mesg = myengine.basefont.render("SCOREBOARD", False, (255,255,255))
            self.first = myengine.basefont.render(f"1). {self.top10[0]}", False, (255, 255, 255))




class Player(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)  # initialize sprite
        self.catcolor = 0 # 0 for gray 1 for black 2 for brown
        self.catprefix = "Assets/sprites/cat/grayCat/"
        self.image = pygame.transform.scale2x(
            pygame.image. load(f"{self.catprefix}catstand1.png")
        )  # initialize the image of the cat stationary
        self.image = self.image.convert_alpha()
        self.rect = self.image.get_rect()
        self.rect.update(
            (myengine.windoww / 2) - 30, (myengine.windowh / 2) - 30, 100, 100
        )
        self.animiter = 0
        myengine.allvisible.add(self)
        myengine.toanimate.add(self)
        
        self.xv = 0
        self.yv = 0
        self.resetx = 0
        self.resety = 0
        
    
    def update(self):
        self.rect.move_ip(self.xv, self.yv)

    def animate(self):
        if self.catcolor == 0:
            self.catprefix = "Assets/sprites/cat/grayCat/"
        elif self.catcolor == 1:
            self.catprefix = "Assets/sprites/cat/blackCat/"
        elif self.catcolor == 2:
            self.catprefix = "Assets/sprites/cat/brownCat/" 
        else:
            self.catcolor = 0
            self.catprefix = "Assets/sprites/cat/grayCat"
        self.animiter = self.animiter + 1
        self.left = 0
        self.right = 0
        self.down = 0
        self.up = 0
        self.idle = 0
# this section of logic determines which way the cat should face favoring left and right over up and down
        if self.xv >= 1:
            self.right = 1  
        if self.yv >= 1:
            self.down = 1
        if self.xv < 0:
            self.left = 1
        if self.yv < 0:
            self.up = 1
        if self.right == 1:
            self.up = 0
            self.down = 0
        if self.left == 1:
            self.up = 0
            self.down = 0
        if self.xv == 0 and self.yv == 0:
            self.up = 0
            self.right = 0
            self.left = 0
            self.down = 0
            self.idle = 1
        if self.left == 1:
            # handles changing the sprite for animation
            if self.animiter < 3:

                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catleft1.png")
                )
                self.image = self.image.convert_alpha()
            else:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catleft2.png")
                )
                self.image = self.image.convert_alpha()
                if self.animiter > 4:
                    self.animiter = 0
        if self.right == 1:
            # handles changing the sprite for animation
            if self.animiter < 3:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catright1.png")
                )
                self.image = self.image.convert_alpha()
            else:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catright2.png")
                )
                self.image = self.image.convert_alpha()
                if self.animiter > 4:
                    self.animiter = 0
        if self.up == 1:
            # handles changing the sprite for animation
            if self.animiter < 3:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catup1.png")
                )
                self.image = self.image.convert_alpha()
            else:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catup2.png")
                )
                self.image = self.image.convert_alpha()
                if self.animiter > 4:
                    self.animiter = 0
        if self.down == 1:
            # handles changing the sprite for animation
            if self.animiter < 3:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catwalkdown1.png")
                )
                self.image = self.image.convert_alpha()
            else:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catwalkdown2.png")
                )
                self.image = self.image.convert_alpha()
                if self.animiter > 4:
                    self.animiter = 0
        if self.idle == 1:
            # handles changing the sprite for animation this handles idle animations
            if self.animiter < 150:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catstand1.png")
                )
                self.image = self.image.convert_alpha()
            else:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catstand2.png")
                )
                self.image = self.image.convert_alpha()
                if self.animiter > 158:
                    self.animiter = 0


class Poop(pygame.sprite.Sprite):
    # this class makes poop objects
    def __init__(
        self, catx, caty, image="Assets/sprites/poop1.png"
    ):  # initialize poop object
        pygame.sprite.Sprite.__init__(self)
        self.image = pygame.image.load(image)
        self.image = self.image.convert_alpha()
        self.rect = self.image.get_rect()
        self.rect.update((catx + 50), (caty + 50), 32, 32)  # places the poop at the cat
        myengine.allvisible.add(self)
        myengine.poopobj.add(self)
        self.used = 0
        myengine.haspooped = 1

    def update(self):
        if self.used == 1:
            self.kill()


class fish(pygame.sprite.Sprite):
    # this class makes fish objects
    def __init__(self, tempx, tempy):
        pygame.sprite.Sprite.__init__(self)
        self.image = pygame.image.load(
            "Assets/sprites/fish1.png"
        )  # init fish sprite with image
        self.image = self.image.convert_alpha()
        self.rect = self.image.get_rect()  # init fish recct
        self.rect.update(tempx, tempy, 32, 32)  # place fish
        myengine.fishobj.add(self)  # add to group of fish
        myengine.allvisible.add(self)  # add to group of visible

class stopwatch:
    def __init__(self):
        self.starttime = time.time()
        self.pausedtime = 0
        self.totalpausedtime = 0
        self.paused = 0
    def reset(self):
        self.startime = time.time()
    def update(self):
        if self.paused == 0:
            self.elapsedsec = (time.time() - self.starttime) - self.totalpausedtime
            print(f"elapsedsec after math {self.elapsedsec} ")
            self.stopwatchmesg = f"time elapsed: {self.elapsedsec:.2f}  seconds"
        elif self.paused == 1:
            self.pausedtime = (time.time() - self.pausestart)
            print(f"myengine.pausedtime {self.pausedtime}")
    def pause(self):
        self.pausestart = time.time()
        self.paused = 1
    def unpause(self):
        self.totalpausedtime = self.totalpausedtime + self.pausedtime
        self.paused = 0



myengine = Background()
mycat = Player()
cameraobj = Camera()


def main():
    myengine.init_bg_frame()
    myengine.init_score()
    while True:
        myengine.test_keys()
        myengine.update_logic()
        myengine.render_screen()
        myengine.clock.tick(60)
main()
# Out:
# pygame 2.1.2 (SDL 2.26.5, Python 3.11.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# elapsedsec after math 3.5762786865234375e-06
# elapsedsec after math 1.9238922595977783
# elapsedsec after math 1.9381496906280518
# elapsedsec after math 1.9528417587280273
# elapsedsec after math 1.9697141647338867
# elapsedsec after math 1.9866628646850586
# elapsedsec after math 2.003455638885498
# elapsedsec after math 2.0217342376708984
# elapsedsec after math 2.034958839416504
# elapsedsec after math 2.0510172843933105
# elapsedsec after math 2.0669028759002686
# elapsedsec after math 2.0840137004852295
# elapsedsec after math 2.099863290786743
# elapsedsec after math 2.116706609725952
# elapsedsec after math 2.1335678100585938
# elapsedsec after math 2.1493263244628906
# elapsedsec after math 2.1652960777282715
# elapsedsec after math 2.1816303730010986
# elapsedsec after math 2.198636293411255
# elapsedsec after math 2.214622735977173
# elapsedsec after math 2.2314913272857666
# elapsedsec after math 2.2470664978027344
# elapsedsec after math 2.2634811401367188
# elapsedsec after math 2.27935528755188
# myengine.pausedtime 3.552436828613281e-05
# myengine.pausedtime 0.0505983829498291
# myengine.pausedtime 0.1006622314453125
# myengine.pausedtime 0.15084338188171387
# myengine.pausedtime 0.19906997680664062
# myengine.pausedtime 0.2449352741241455
# myengine.pausedtime 0.2935457229614258
# myengine.pausedtime 0.33603382110595703
# myengine.pausedtime 0.3785440921783447
# myengine.pausedtime 0.42026281356811523
# myengine.pausedtime 0.46322083473205566
# myengine.pausedtime 0.5050384998321533
# myengine.pausedtime 0.5539143085479736
# myengine.pausedtime 0.5954484939575195
# myengine.pausedtime 0.6368176937103271
# myengine.pausedtime 0.6791462898254395
# myengine.pausedtime 0.721693754196167
# myengine.pausedtime 0.7668015956878662
# myengine.pausedtime 0.808377742767334
# myengine.pausedtime 0.8503820896148682
# myengine.pausedtime 0.8924551010131836
# myengine.pausedtime 0.9359996318817139
# myengine.pausedtime 0.9812474250793457
# myengine.pausedtime 1.0219390392303467
# myengine.pausedtime 1.0632669925689697
# myengine.pausedtime 1.104292392730713
# myengine.pausedtime 1.1470839977264404
# myengine.pausedtime 1.1947553157806396
# myengine.pausedtime 1.235887050628662
# myengine.pausedtime 1.277416706085205
# myengine.pausedtime 1.3204665184020996
# myengine.pausedtime 1.3631887435913086
# myengine.pausedtime 1.4088037014007568
# myengine.pausedtime 1.4503493309020996
# myengine.pausedtime 1.4924957752227783
# myengine.pausedtime 1.5344808101654053
# myengine.pausedtime 1.576829433441162
# elapsedsec after math 2.344770908355713
# elapsedsec after math 2.359253406524658
# elapsedsec after math 2.375056743621826
# elapsedsec after math 2.3910064697265625
# elapsedsec after math 2.4078004360198975
# elapsedsec after math 2.4246387481689453
# elapsedsec after math 2.44260311126709
# elapsedsec after math 2.4567713737487793
# elapsedsec after math 2.4726526737213135
# elapsedsec after math 2.4887940883636475
# elapsedsec after math 2.5048978328704834
# elapsedsec after math 2.5212762355804443
# elapsedsec after math 2.5371434688568115
# elapsedsec after math 2.553307294845581
# elapsedsec after math 2.5692126750946045
# elapsedsec after math 2.585057258605957
# elapsedsec after math 2.601860523223877
# elapsedsec after math 2.618595600128174
# elapsedsec after math 2.6340651512145996
# elapsedsec after math 2.650097370147705
# elapsedsec after math 2.6662046909332275
# elapsedsec after math 2.6819887161254883
# elapsedsec after math 2.698827028274536
# elapsedsec after math 2.715597629547119
# elapsedsec after math 2.73172926902771
# elapsedsec after math 2.7478106021881104
# elapsedsec after math 2.7638046741485596
# elapsedsec after math 2.7807204723358154
# elapsedsec after math 2.7962825298309326
# elapsedsec after math 2.812415838241577
# elapsedsec after math 2.828587770462036
# elapsedsec after math 2.8450303077697754
# elapsedsec after math 2.8600544929504395
# elapsedsec after math 2.8760180473327637
# elapsedsec after math 2.8919131755828857
# elapsedsec after math 2.9088311195373535
# elapsedsec after math 2.9249813556671143
# elapsedsec after math 2.941138744354248
# myengine.pausedtime 3.933906555175781e-05
# myengine.pausedtime 0.045328378677368164
# myengine.pausedtime 0.08939146995544434
# myengine.pausedtime 0.13309025764465332
# myengine.pausedtime 0.17508292198181152
# myengine.pausedtime 0.21969079971313477
# myengine.pausedtime 0.26166439056396484
# myengine.pausedtime 0.3030891418457031
# myengine.pausedtime 0.34409236907958984
# myengine.pausedtime 0.38677310943603516
# myengine.pausedtime 0.43198060989379883
# myengine.pausedtime 0.47295546531677246
# myengine.pausedtime 0.5140390396118164
# myengine.pausedtime 0.5549514293670654
# myengine.pausedtime 0.5967724323272705
# myengine.pausedtime 0.641373872756958
# myengine.pausedtime 0.6854181289672852
# myengine.pausedtime 0.7380943298339844
# myengine.pausedtime 0.7797324657440186
# myengine.pausedtime 0.8277668952941895
# myengine.pausedtime 0.8719732761383057
# myengine.pausedtime 0.913020133972168
# myengine.pausedtime 0.9542708396911621
# myengine.pausedtime 0.9958183765411377
# myengine.pausedtime 1.0374748706817627
# myengine.pausedtime 1.0834507942199707
# myengine.pausedtime 1.1246190071105957
# myengine.pausedtime 1.1650669574737549
# myengine.pausedtime 1.2064642906188965
# myengine.pausedtime 1.2486073970794678
# myengine.pausedtime 1.297935962677002
# myengine.pausedtime 1.3392856121063232
# myengine.pausedtime 1.380580186843872
# myengine.pausedtime 1.422060251235962
# myengine.pausedtime 1.4635536670684814
# myengine.pausedtime 1.510528564453125
# myengine.pausedtime 1.5518007278442383
# myengine.pausedtime 1.5932583808898926
# myengine.pausedtime 1.6548116207122803
# myengine.pausedtime 1.701319932937622
# myengine.pausedtime 1.7487053871154785
# myengine.pausedtime 1.7911441326141357
# myengine.pausedtime 1.8338127136230469
# myengine.pausedtime 1.8755767345428467
# myengine.pausedtime 1.9178967475891113
# myengine.pausedtime 1.9630823135375977
# elapsedsec after math 3.0037639141082764
# elapsedsec after math 3.018150806427002
# elapsedsec after math 3.0342702865600586
# elapsedsec after math 3.0500919818878174
# elapsedsec after math 3.066647529602051
# elapsedsec after math 3.082524061203003
# elapsedsec after math 3.1005032062530518
# elapsedsec after math 3.1138460636138916
# elapsedsec after math 3.130197525024414
# elapsedsec after math 3.1463019847869873
# elapsedsec after math 3.1619722843170166
# elapsedsec after math 3.178685426712036
# elapsedsec after math 3.1945581436157227
# elapsedsec after math 3.2104034423828125
# elapsedsec after math 3.2262282371520996
# elapsedsec after math 3.2423126697540283
# elapsedsec after math 3.258063793182373
# elapsedsec after math 3.2739241123199463
# elapsedsec after math 3.290745496749878
# elapsedsec after math 3.307537317276001
# elapsedsec after math 3.323394775390625
# elapsedsec after math 3.3393731117248535
# elapsedsec after math 3.355512857437134
# elapsedsec after math 3.3716604709625244
# elapsedsec after math 3.3869149684906006
# elapsedsec after math 3.4037530422210693
# elapsedsec after math 3.421135425567627
# elapsedsec after math 3.4370594024658203
# elapsedsec after math 3.4537129402160645
# elapsedsec after math 3.470585346221924
# elapsedsec after math 3.486570119857788
# elapsedsec after math 3.5025532245635986
# elapsedsec after math 3.518436908721924
# elapsedsec after math 3.5343098640441895
# myengine.pausedtime 2.8133392333984375e-05
# myengine.pausedtime 0.044971466064453125
# myengine.pausedtime 0.08854484558105469
# myengine.pausedtime 0.13168644905090332
# myengine.pausedtime 0.18553853034973145
# myengine.pausedtime 0.2428576946258545
# myengine.pausedtime 0.2871100902557373
# myengine.pausedtime 0.3318634033203125
# myengine.pausedtime 0.3747446537017822
# myengine.pausedtime 0.4180126190185547
# myengine.pausedtime 0.4607102870941162
# myengine.pausedtime 0.512620210647583
# myengine.pausedtime 0.555974006652832
# myengine.pausedtime 0.5991015434265137
# myengine.pausedtime 0.6410448551177979
# myengine.pausedtime 0.6954607963562012
# myengine.pausedtime 0.7384884357452393
# myengine.pausedtime 0.7796306610107422
# myengine.pausedtime 0.8223562240600586
# myengine.pausedtime 0.8638131618499756
# myengine.pausedtime 0.907282829284668
# myengine.pausedtime 0.9526448249816895
# myengine.pausedtime 0.9940207004547119
# myengine.pausedtime 1.0358645915985107
# myengine.pausedtime 1.077270746231079
# myengine.pausedtime 1.1203677654266357
# myengine.pausedtime 1.1679091453552246
# myengine.pausedtime 1.2111711502075195
# myengine.pausedtime 1.2530629634857178
# myengine.pausedtime 1.2946062088012695
# myengine.pausedtime 1.3366825580596924
# myengine.pausedtime 1.384251356124878
# myengine.pausedtime 1.4266343116760254
# myengine.pausedtime 1.4682292938232422
# myengine.pausedtime 1.5096168518066406
# myengine.pausedtime 1.5513696670532227
# myengine.pausedtime 1.598790168762207
# myengine.pausedtime 1.6423094272613525
# myengine.pausedtime 1.684823751449585
# myengine.pausedtime 1.7268540859222412
# myengine.pausedtime 1.769672155380249
# myengine.pausedtime 1.8195793628692627
# myengine.pausedtime 1.861030101776123
# myengine.pausedtime 1.9026978015899658
# myengine.pausedtime 1.94435715675354
# myengine.pausedtime 1.9860405921936035
# myengine.pausedtime 2.0350968837738037
# myengine.pausedtime 2.0764496326446533
# myengine.pausedtime 2.1178579330444336
# myengine.pausedtime 2.1607656478881836
# myengine.pausedtime 2.2044198513031006
# myengine.pausedtime 2.2503554821014404
# myengine.pausedtime 2.2917380332946777
# myengine.pausedtime 2.33316707611084
# myengine.pausedtime 2.376563310623169
# myengine.pausedtime 2.41858172416687
# myengine.pausedtime 2.4650614261627197
# myengine.pausedtime 2.50644588470459
# myengine.pausedtime 2.5478761196136475
# myengine.pausedtime 2.58925461769104
# myengine.pausedtime 2.630434274673462
# myengine.pausedtime 2.6774988174438477
# myengine.pausedtime 2.71855092048645
# myengine.pausedtime 2.759652614593506
# myengine.pausedtime 2.800532341003418
# myengine.pausedtime 2.8417930603027344
# myengine.pausedtime 2.8912014961242676
# myengine.pausedtime 2.93302583694458
# myengine.pausedtime 2.9749953746795654
# myengine.pausedtime 3.016432523727417
# myengine.pausedtime 3.0581233501434326
# myengine.pausedtime 3.1043813228607178
# myengine.pausedtime 3.1456706523895264
# myengine.pausedtime 3.1888129711151123
# myengine.pausedtime 3.231417179107666
# myengine.pausedtime 3.2729651927948
# myengine.pausedtime 3.3224101066589355
# myengine.pausedtime 3.3645174503326416
# myengine.pausedtime 3.40582275390625
# myengine.pausedtime 3.4471182823181152
# myengine.pausedtime 3.4887640476226807
# myengine.pausedtime 3.5335450172424316
# myengine.pausedtime 3.575253486633301
# myengine.pausedtime 3.6172873973846436
# myengine.pausedtime 3.658921241760254
# myengine.pausedtime 3.701033353805542
# myengine.pausedtime 3.7474052906036377
# myengine.pausedtime 3.7888031005859375
# myengine.pausedtime 3.8300273418426514
# myengine.pausedtime 3.871084213256836
# myengine.pausedtime 3.9121592044830322
# myengine.pausedtime 3.9635016918182373
# myengine.pausedtime 4.006486654281616
# myengine.pausedtime 4.0473997592926025
# myengine.pausedtime 4.088538408279419
# myengine.pausedtime 4.130160570144653
# myengine.pausedtime 4.182977914810181
# myengine.pausedtime 4.224904298782349
# myengine.pausedtime 4.265918493270874
# elapsedsec after math 3.5955095291137695
# elapsedsec after math 3.6107380390167236
# elapsedsec after math 3.6266181468963623
# elapsedsec after math 3.64304780960083
# elapsedsec after math 3.6581907272338867
# elapsedsec after math 3.674072742462158
# elapsedsec after math 3.692185878753662
# elapsedsec after math 3.7064902782440186
# elapsedsec after math 3.7225468158721924
# elapsedsec after math 3.7385506629943848
# elapsedsec after math 3.7543983459472656
# elapsedsec after math 3.7702560424804688
# elapsedsec after math 3.786112070083618
# elapsedsec after math 3.8020849227905273
# elapsedsec after math 3.819169759750366
# elapsedsec after math 3.8350183963775635
# elapsedsec after math 3.851205825805664
# elapsedsec after math 3.8670265674591064
# elapsedsec after math 3.88321590423584
# elapsedsec after math 3.899258852005005
# elapsedsec after math 3.915078639984131
# elapsedsec after math 3.9309959411621094
# elapsedsec after math 3.9471781253814697
# elapsedsec after math 3.963101387023926
# elapsedsec after math 3.9798519611358643
# elapsedsec after math 3.9970905780792236
# elapsedsec after math 4.012875318527222
# elapsedsec after math 4.029762506484985
# elapsedsec after math 4.045556545257568
# elapsedsec after math 4.060930967330933
# elapsedsec after math 4.0776894092559814
# elapsedsec after math 4.093702077865601
# elapsedsec after math 4.109800577163696
# elapsedsec after math 4.125030994415283
# elapsedsec after math 4.140983819961548
# elapsedsec after math 4.157046318054199
# elapsedsec after math 4.173463582992554
# elapsedsec after math 4.189439296722412
# elapsedsec after math 4.205248594284058
# elapsedsec after math 4.221155881881714
# elapsedsec after math 4.237023115158081
# elapsedsec after math 4.252923965454102
# elapsedsec after math 4.2697834968566895
# elapsedsec after math 4.285540819168091
# elapsedsec after math 4.301472902297974
# elapsedsec after math 4.317335844039917
# elapsedsec after math 4.3332839012146
# elapsedsec after math 4.349695682525635
# elapsedsec after math 4.365426301956177
# elapsedsec after math 4.381267309188843
# elapsedsec after math 4.397162437438965
# elapsedsec after math 4.413205623626709
# elapsedsec after math 4.429100751876831
# elapsedsec after math 4.445396184921265
# elapsedsec after math 4.461864233016968
# elapsedsec after math 4.477116346359253
# elapsedsec after math 4.493302345275879
# elapsedsec after math 4.509575605392456
# elapsedsec after math 4.5259315967559814
# elapsedsec after math 4.541041612625122
# elapsedsec after math 4.557312965393066
# elapsedsec after math 4.573775053024292
# elapsedsec after math 4.5899248123168945
# elapsedsec after math 4.606226921081543
# elapsedsec after math 4.6223249435424805
# elapsedsec after math 4.638521671295166
# elapsedsec after math 4.654101371765137
# elapsedsec after math 4.67012095451355
# elapsedsec after math 4.686234951019287
# elapsedsec after math 4.702420711517334
# elapsedsec after math 4.718209743499756
# elapsedsec after math 4.7340216636657715
# elapsedsec after math 4.749898672103882
# myengine.pausedtime 3.457069396972656e-05
# myengine.pausedtime 0.043015480041503906
# myengine.pausedtime 0.08682107925415039
# myengine.pausedtime 0.13402867317199707
# myengine.pausedtime 0.1774449348449707
# myengine.pausedtime 0.21906471252441406
# myengine.pausedtime 0.2619771957397461
# myengine.pausedtime 0.3053257465362549
# myengine.pausedtime 0.3489217758178711
# myengine.pausedtime 0.3986365795135498
# myengine.pausedtime 0.4413115978240967
# myengine.pausedtime 0.482684850692749
# myengine.pausedtime 0.5251667499542236
# myengine.pausedtime 0.5681912899017334
# myengine.pausedtime 0.6161754131317139
# myengine.pausedtime 0.6586554050445557
# myengine.pausedtime 0.7030725479125977
# myengine.pausedtime 0.7488319873809814
# myengine.pausedtime 0.8013772964477539
# myengine.pausedtime 0.8435258865356445
# myengine.pausedtime 0.8845736980438232
# myengine.pausedtime 0.9262280464172363
# myengine.pausedtime 0.967449426651001
# myengine.pausedtime 1.009852409362793
# myengine.pausedtime 1.0645291805267334
# myengine.pausedtime 1.106285572052002
# myengine.pausedtime 1.1481597423553467
# myengine.pausedtime 1.1900293827056885
# myengine.pausedtime 1.2424712181091309
# myengine.pausedtime 1.2863044738769531
# myengine.pausedtime 1.3278744220733643
# myengine.pausedtime 1.369192361831665
# myengine.pausedtime 1.410480260848999
# myengine.pausedtime 1.4531264305114746
# myengine.pausedtime 1.5010130405426025
# myengine.pausedtime 1.5427420139312744
# myengine.pausedtime 1.5844981670379639
# myengine.pausedtime 1.6260173320770264
# myengine.pausedtime 1.66810941696167
# elapsedsec after math 4.820374250411987
# elapsedsec after math 4.833898305892944
# elapsedsec after math 4.850675106048584
# elapsedsec after math 4.866574764251709
# elapsedsec after math 4.8818230628967285
# elapsedsec after math 4.9000818729400635
# elapsedsec after math 4.91452956199646
# elapsedsec after math 4.9307920932769775
# elapsedsec after math 4.94598126411438
# elapsedsec after math 4.961873292922974
# elapsedsec after math 4.9778642654418945
# elapsedsec after math 4.994413375854492
# elapsedsec after math 5.009815216064453
# elapsedsec after math 5.026126861572266
# elapsedsec after math 5.042081117630005
# elapsedsec after math 5.058356761932373
# elapsedsec after math 5.074425935745239
# elapsedsec after math 5.090274095535278
# elapsedsec after math 5.106497287750244
# elapsedsec after math 5.1223464012146
# elapsedsec after math 5.13820481300354
# elapsedsec after math 5.1542346477508545
# elapsedsec after math 5.170106649398804
# elapsedsec after math 5.186007976531982
# elapsedsec after math 5.202925682067871
# elapsedsec after math 5.2197582721710205
# elapsedsec after math 5.236607313156128
# elapsedsec after math 5.2524449825286865
# elapsedsec after math 5.268438816070557
# elapsedsec after math 5.284643888473511
# elapsedsec after math 5.300476551055908
# elapsedsec after math 5.316368579864502
# elapsedsec after math 5.33230185508728
# elapsedsec after math 5.348210334777832
# elapsedsec after math 5.3640923500061035
# elapsedsec after math 5.379989862442017
# elapsedsec after math 5.396759271621704
# elapsedsec after math 5.412859201431274
# myengine.pausedtime 4.553794860839844e-05
# myengine.pausedtime 0.042136192321777344
# myengine.pausedtime 0.08423471450805664
# myengine.pausedtime 0.12852787971496582
# myengine.pausedtime 0.17032837867736816
# myengine.pausedtime 0.22126173973083496
# myengine.pausedtime 0.2627880573272705
# myengine.pausedtime 0.3042631149291992
# myengine.pausedtime 0.34732747077941895
# myengine.pausedtime 0.3993957042694092
# myengine.pausedtime 0.4435124397277832
# myengine.pausedtime 0.48519134521484375
# myengine.pausedtime 0.5269975662231445
# myengine.pausedtime 0.5683279037475586
# myengine.pausedtime 0.6100356578826904
# myengine.pausedtime 0.6612856388092041
# myengine.pausedtime 0.7029337882995605
# myengine.pausedtime 0.7444911003112793
# myengine.pausedtime 0.7862536907196045
# myengine.pausedtime 0.828585147857666
# myengine.pausedtime 0.8808486461639404
# myengine.pausedtime 0.9229941368103027
# myengine.pausedtime 0.9646055698394775
# myengine.pausedtime 1.0078771114349365
# myengine.pausedtime 1.0604422092437744
# myengine.pausedtime 1.1051013469696045
# myengine.pausedtime 1.1465318202972412
# myengine.pausedtime 1.187971830368042
# myengine.pausedtime 1.2295444011688232
# myengine.pausedtime 1.2715981006622314
# myengine.pausedtime 1.3247568607330322
# myengine.pausedtime 1.3708019256591797
# myengine.pausedtime 1.413097858428955
# myengine.pausedtime 1.4552218914031982
# myengine.pausedtime 1.5083730220794678
# myengine.pausedtime 1.551161289215088
# myengine.pausedtime 1.5925912857055664
# myengine.pausedtime 1.6338801383972168
# myengine.pausedtime 1.6755530834197998
# myengine.pausedtime 1.7172188758850098
# myengine.pausedtime 1.7711503505706787
# myengine.pausedtime 1.8125972747802734
# myengine.pausedtime 1.8532969951629639
# myengine.pausedtime 1.895226240158081
# myengine.pausedtime 1.9508347511291504
# myengine.pausedtime 1.9931426048278809
# myengine.pausedtime 2.0340826511383057
# myengine.pausedtime 2.074964761734009
# myengine.pausedtime 2.116295337677002
# myengine.pausedtime 2.1574056148529053
# myengine.pausedtime 2.2077319622039795
# myengine.pausedtime 2.249009370803833
# myengine.pausedtime 2.2944068908691406
# myengine.pausedtime 2.3358869552612305
# myengine.pausedtime 2.3963444232940674
# myengine.pausedtime 2.4435038566589355
# myengine.pausedtime 2.4853696823120117
# myengine.pausedtime 2.5290563106536865
# myengine.pausedtime 2.570812463760376
# myengine.pausedtime 2.6129298210144043
# myengine.pausedtime 2.6587557792663574
# myengine.pausedtime 2.700336456298828
# myengine.pausedtime 2.743678569793701
# myengine.pausedtime 2.7867279052734375
# myengine.pausedtime 2.829570770263672
# myengine.pausedtime 2.8779213428497314
# myengine.pausedtime 2.919984817504883
# myengine.pausedtime 2.9632151126861572
# myengine.pausedtime 3.0049400329589844
# myengine.pausedtime 3.0476789474487305
# myengine.pausedtime 3.0949511528015137
# myengine.pausedtime 3.136869192123413
# myengine.pausedtime 3.1785311698913574
# myengine.pausedtime 3.220182180404663
# myengine.pausedtime 3.2620677947998047
# myengine.pausedtime 3.309695243835449
# myengine.pausedtime 3.3528618812561035
# myengine.pausedtime 3.396481990814209
# myengine.pausedtime 3.43843936920166
# myengine.pausedtime 3.4806277751922607
# myengine.pausedtime 3.5264410972595215
# myengine.pausedtime 3.568260908126831
# myengine.pausedtime 3.6096692085266113
# myengine.pausedtime 3.6509850025177
# myengine.pausedtime 3.692793130874634
# myengine.pausedtime 3.7445871829986572
# myengine.pausedtime 3.7862043380737305
# myengine.pausedtime 3.82800555229187
# myengine.pausedtime 3.8694803714752197
# myengine.pausedtime 3.9116690158843994
# myengine.pausedtime 3.9651219844818115
# myengine.pausedtime 4.007280349731445
# myengine.pausedtime 4.048910140991211
# myengine.pausedtime 4.0905961990356445
# myengine.pausedtime 4.144466876983643
# myengine.pausedtime 4.189620018005371
# myengine.pausedtime 4.2311623096466064
# myengine.pausedtime 4.27303409576416
# myengine.pausedtime 4.314704418182373
# myengine.pausedtime 4.357394218444824
# myengine.pausedtime 4.4071455001831055
# myengine.pausedtime 4.448918104171753
# myengine.pausedtime 4.490842342376709
# myengine.pausedtime 4.532904148101807
# myengine.pausedtime 4.574971914291382
# myengine.pausedtime 4.627866506576538
# myengine.pausedtime 4.669455051422119
# myengine.pausedtime 4.710937261581421
# myengine.pausedtime 4.752646446228027
# myengine.pausedtime 4.808012247085571
# myengine.pausedtime 4.850487470626831
# myengine.pausedtime 4.891462564468384
# myengine.pausedtime 4.93306040763855
# myengine.pausedtime 4.974555492401123
# myengine.pausedtime 5.016499280929565
# myengine.pausedtime 5.066671133041382
# myengine.pausedtime 5.1085364818573
# myengine.pausedtime 5.14946436882019
# myengine.pausedtime 5.1902055740356445
# myengine.pausedtime 5.2318079471588135
# myengine.pausedtime 5.280991077423096
# myengine.pausedtime 5.32293438911438
# myengine.pausedtime 5.36758017539978
# myengine.pausedtime 5.411360263824463
# myengine.pausedtime 5.455241918563843
# myengine.pausedtime 5.501864433288574
# myengine.pausedtime 5.54351282119751
# myengine.pausedtime 5.584589958190918
# myengine.pausedtime 5.6260905265808105
# myengine.pausedtime 5.668061971664429
# elapsedsec after math 5.4805748462677
# elapsedsec after math 5.494001388549805
# elapsedsec after math 5.510148048400879
# elapsedsec after math 5.525827646255493
# elapsedsec after math 5.544708013534546
# elapsedsec after math 5.558147430419922
# elapsedsec after math 5.57410192489624
# elapsedsec after math 5.5902955532073975
# elapsedsec after math 5.606057167053223
# elapsedsec after math 5.621912002563477
# elapsedsec after math 5.6386330127716064
# elapsedsec after math 5.655422210693359
# elapsedsec after math 5.671203136444092
# elapsedsec after math 5.687689304351807
# elapsedsec after math 5.7035133838653564
# elapsedsec after math 5.718958139419556
# elapsedsec after math 5.73507285118103
# elapsedsec after math 5.751044273376465
# elapsedsec after math 5.766861915588379
# elapsedsec after math 5.78371000289917
# elapsedsec after math 5.800475835800171
# elapsedsec after math 5.816399812698364
# elapsedsec after math 5.832159519195557
# elapsedsec after math 5.848191499710083
# elapsedsec after math 5.864779949188232
# elapsedsec after math 5.8814191818237305
# elapsedsec after math 5.897632837295532
# elapsedsec after math 5.9130706787109375
# elapsedsec after math 5.928781986236572
# elapsedsec after math 5.945160865783691
# elapsedsec after math 5.961657524108887
# elapsedsec after math 5.976973056793213
# elapsedsec after math 5.992762804031372
# elapsedsec after math 6.008973598480225
# elapsedsec after math 6.024888753890991
# elapsedsec after math 6.041163206100464
# elapsedsec after math 6.056984901428223
# elapsedsec after math 6.07312798500061
# elapsedsec after math 6.089001893997192
# elapsedsec after math 6.105602979660034
# elapsedsec after math 6.121055603027344
# elapsedsec after math 6.136920690536499
# elapsedsec after math 6.153689861297607
# elapsedsec after math 6.1706366539001465
# elapsedsec after math 6.186469554901123
# elapsedsec after math 6.202688932418823
# elapsedsec after math 6.21993088722229
# elapsedsec after math 6.2347705364227295
# elapsedsec after math 6.251020669937134
# elapsedsec after math 6.266904830932617
# elapsedsec after math 6.2836596965789795
# elapsedsec after math 6.299684762954712
# elapsedsec after math 6.316606521606445
# elapsedsec after math 6.332728385925293
# elapsedsec after math 6.3494932651519775
# elapsedsec after math 6.365349054336548
# elapsedsec after math 6.381433486938477
# elapsedsec after math 6.3979878425598145
# elapsedsec after math 6.413985729217529
# elapsedsec after math 6.429841041564941
# elapsedsec after math 6.445796251296997
# elapsedsec after math 6.462050676345825
# elapsedsec after math 6.478058576583862
# elapsedsec after math 6.494339942932129
# elapsedsec after math 6.510693311691284
# elapsedsec after math 6.527125597000122
# elapsedsec after math 6.543119430541992
# elapsedsec after math 6.5592451095581055
# elapsedsec after math 6.57543683052063
# elapsedsec after math 6.591372728347778
# elapsedsec after math 6.60741114616394
# elapsedsec after math 6.623746633529663
# elapsedsec after math 6.640635013580322
# elapsedsec after math 6.656503677368164
# elapsedsec after math 6.672486066818237
# elapsedsec after math 6.688622951507568
# elapsedsec after math 6.705397844314575
# elapsedsec after math 6.72140908241272
# elapsedsec after math 6.737219333648682
# elapsedsec after math 6.753451824188232
# elapsedsec after math 6.769280672073364
# elapsedsec after math 6.785183429718018
# elapsedsec after math 6.800997495651245
# elapsedsec after math 6.8168604373931885
# elapsedsec after math 6.833667278289795
# elapsedsec after math 6.850541591644287
# elapsedsec after math 6.866339445114136
# elapsedsec after math 6.882248878479004
# elapsedsec after math 6.898040771484375
# elapsedsec after math 6.913744688034058
# elapsedsec after math 6.930195093154907
# elapsedsec after math 6.94622540473938
# elapsedsec after math 6.962294816970825
# elapsedsec after math 6.978503942489624
# elapsedsec after math 6.994741916656494
# elapsedsec after math 7.0109429359436035
# elapsedsec after math 7.026986122131348
# elapsedsec after math 7.043140172958374
# elapsedsec after math 7.05913233757019
# elapsedsec after math 7.075140714645386
# elapsedsec after math 7.090991020202637
# elapsedsec after math 7.107118606567383
# elapsedsec after math 7.122807502746582
# elapsedsec after math 7.139021635055542
# elapsedsec after math 7.155599355697632
# elapsedsec after math 7.1713268756866455
# elapsedsec after math 7.187287092208862
# elapsedsec after math 7.203658103942871
# elapsedsec after math 7.220633506774902
# elapsedsec after math 7.236351728439331
# elapsedsec after math 7.25180196762085
# elapsedsec after math 7.268327474594116
# elapsedsec after math 7.2846434116363525
# elapsedsec after math 7.300030469894409
# elapsedsec after math 7.3161399364471436
# elapsedsec after math 7.332281112670898
# elapsedsec after math 7.3484718799591064
# elapsedsec after math 7.363798141479492
# elapsedsec after math 7.380699634552002
# elapsedsec after math 7.397697687149048
# elapsedsec after math 7.413439035415649
# elapsedsec after math 7.429400444030762
# elapsedsec after math 7.44528865814209
# elapsedsec after math 7.4618141651153564
# elapsedsec after math 7.477669715881348
# elapsedsec after math 7.493520021438599
# elapsedsec after math 7.5097620487213135
# elapsedsec after math 7.525882005691528
# elapsedsec after math 7.542077302932739
# elapsedsec after math 7.558371067047119
# elapsedsec after math 7.5743396282196045
# elapsedsec after math 7.59031081199646
# elapsedsec after math 7.606202125549316
# elapsedsec after math 7.622130632400513
# elapsedsec after math 7.63814640045166
# elapsedsec after math 7.653888463973999
# elapsedsec after math 7.670598983764648
# elapsedsec after math 7.686459541320801
# elapsedsec after math 7.702483892440796
# elapsedsec after math 7.7184059619903564
# elapsedsec after math 7.734166860580444
# elapsedsec after math 7.749905347824097
# elapsedsec after math 7.765758037567139
# elapsedsec after math 7.781924486160278
# elapsedsec after math 7.798745155334473
# elapsedsec after math 7.81593132019043
# elapsedsec after math 7.83087682723999
# elapsedsec after math 7.84704327583313
# elapsedsec after math 7.86310076713562
# elapsedsec after math 7.879154205322266
# elapsedsec after math 7.895181894302368
# elapsedsec after math 7.911494255065918
# elapsedsec after math 7.927642107009888
# elapsedsec after math 7.943619251251221
# elapsedsec after math 7.959189414978027
# elapsedsec after math 7.975221872329712
# elapsedsec after math 7.991800785064697
# elapsedsec after math 8.007027626037598
# elapsedsec after math 8.022884368896484
# elapsedsec after math 8.039739847183228
# elapsedsec after math 8.05665922164917
# elapsedsec after math 8.073545455932617
# elapsedsec after math 8.089412927627563
# elapsedsec after math 8.105414152145386
# elapsedsec after math 8.12126612663269
# elapsedsec after math 8.137125492095947
# elapsedsec after math 8.152948379516602
# elapsedsec after math 8.16945767402649
# elapsedsec after math 8.185481071472168
# elapsedsec after math 8.201621532440186
# elapsedsec after math 8.21763801574707
# elapsedsec after math 8.23345398902893
# elapsedsec after math 8.249423503875732
# elapsedsec after math 8.26478123664856
# elapsedsec after math 8.28087854385376
# elapsedsec after math 8.297426223754883
# elapsedsec after math 8.313586711883545
# elapsedsec after math 8.329737663269043
# elapsedsec after math 8.346311330795288
# elapsedsec after math 8.362313985824585
# elapsedsec after math 8.377827405929565
# elapsedsec after math 8.393954515457153
# elapsedsec after math 8.410343170166016
# elapsedsec after math 8.426646709442139
# elapsedsec after math 8.442551374435425
# elapsedsec after math 8.458455085754395
# elapsedsec after math 8.474477052688599
# elapsedsec after math 8.489765167236328
# elapsedsec after math 8.506663084030151
# elapsedsec after math 8.523894548416138
# elapsedsec after math 8.539733648300171
# elapsedsec after math 8.556681394577026
# elapsedsec after math 8.57349157333374
# elapsedsec after math 8.589622259140015
# elapsedsec after math 8.605419874191284
# elapsedsec after math 8.62140703201294
# elapsedsec after math 8.637373208999634
# elapsedsec after math 8.653149843215942
# elapsedsec after math 8.668982982635498
# elapsedsec after math 8.684893369674683
# elapsedsec after math 8.701955795288086
# elapsedsec after math 8.717747926712036
# elapsedsec after math 8.734524726867676
# elapsedsec after math 8.750668048858643
# elapsedsec after math 8.767583131790161
# elapsedsec after math 8.783582210540771
# elapsedsec after math 8.798894166946411
# elapsedsec after math 8.814875841140747
# elapsedsec after math 8.831156015396118
# elapsedsec after math 8.847097873687744
# elapsedsec after math 8.863008260726929
# elapsedsec after math 8.879664182662964
# elapsedsec after math 8.89478349685669
# elapsedsec after math 8.911238431930542
# elapsedsec after math 8.927499771118164
# elapsedsec after math 8.942822694778442
# elapsedsec after math 8.959704875946045
# elapsedsec after math 8.97587251663208
# elapsedsec after math 8.991780996322632
# elapsedsec after math 9.007725477218628
# elapsedsec after math 9.024540662765503
# elapsedsec after math 9.040479183197021
# elapsedsec after math 9.05689024925232
# elapsedsec after math 9.071789503097534
# elapsedsec after math 9.088716745376587
# elapsedsec after math 9.105484962463379
# elapsedsec after math 9.121442556381226
# elapsedsec after math 9.13720178604126
# elapsedsec after math 9.153021812438965
# elapsedsec after math 9.168906927108765
# elapsedsec after math 9.185601949691772
# elapsedsec after math 9.201371192932129
# elapsedsec after math 9.217212677001953
# elapsedsec after math 9.233323812484741
# elapsedsec after math 9.249196290969849
# elapsedsec after math 9.265034914016724
# elapsedsec after math 9.28110933303833
# elapsedsec after math 9.296977996826172
# elapsedsec after math 9.313136339187622
# elapsedsec after math 9.329051733016968
# elapsedsec after math 9.345180988311768
# elapsedsec after math 9.361355781555176
# elapsedsec after math 9.377124547958374
# elapsedsec after math 9.393197774887085
# elapsedsec after math 9.409535646438599
# elapsedsec after math 9.425467252731323
# elapsedsec after math 9.441537141799927
# elapsedsec after math 9.457696914672852
# elapsedsec after math 9.474531888961792
# elapsedsec after math 9.490349292755127
# elapsedsec after math 9.506228685379028
# elapsedsec after math 9.522332906723022
# elapsedsec after math 9.538407802581787
# elapsedsec after math 9.554272413253784
# elapsedsec after math 9.570080757141113
# elapsedsec after math 9.58622670173645
# elapsedsec after math 9.602024555206299
# elapsedsec after math 9.617810726165771
# elapsedsec after math 9.63445520401001
# elapsedsec after math 9.6501624584198
# elapsedsec after math 9.666213512420654
# elapsedsec after math 9.682322978973389
# elapsedsec after math 9.698118686676025
# elapsedsec after math 9.714169025421143
# elapsedsec after math 9.730046510696411
# elapsedsec after math 9.746126174926758
# elapsedsec after math 9.762531757354736
# elapsedsec after math 9.778465270996094
# elapsedsec after math 9.79462480545044
# elapsedsec after math 9.810715675354004
# elapsedsec after math 9.827634572982788
# elapsedsec after math 9.843682050704956
# elapsedsec after math 9.86044716835022
# elapsedsec after math 9.876448392868042
# elapsedsec after math 9.8926522731781
# elapsedsec after math 9.90810775756836
# elapsedsec after math 9.92406439781189
# elapsedsec after math 9.940350532531738
# elapsedsec after math 9.956198453903198
# elapsedsec after math 9.97215986251831
# elapsedsec after math 9.988025903701782
# elapsedsec after math 10.003958940505981
# elapsedsec after math 10.019960165023804
# elapsedsec after math 10.036044359207153
# elapsedsec after math 10.052722454071045
# elapsedsec after math 10.069442987442017
# elapsedsec after math 10.085342645645142
# elapsedsec after math 10.10123085975647
# elapsedsec after math 10.117436408996582
# elapsedsec after math 10.133434772491455
# elapsedsec after math 10.149435758590698
# elapsedsec after math 10.165260076522827
# elapsedsec after math 10.181690216064453
# elapsedsec after math 10.198554277420044
# elapsedsec after math 10.214414834976196
# elapsedsec after math 10.230313301086426
# elapsedsec after math 10.246253252029419
# elapsedsec after math 10.262237310409546
# elapsedsec after math 10.278529405593872
# elapsedsec after math 10.294106245040894
# elapsedsec after math 10.310614824295044
# elapsedsec after math 10.325907707214355
# elapsedsec after math 10.342731475830078
# elapsedsec after math 10.359647750854492
# elapsedsec after math 10.375677108764648
# elapsedsec after math 10.392546892166138
# elapsedsec after math 10.408347129821777
# elapsedsec after math 10.42428708076477
# elapsedsec after math 10.440063953399658
# elapsedsec after math 10.455904722213745
# elapsedsec after math 10.472853660583496
# elapsedsec after math 10.488686800003052
# elapsedsec after math 10.50481390953064
# elapsedsec after math 10.52163052558899
# elapsedsec after math 10.5374436378479
# elapsedsec after math 10.553386688232422
# elapsedsec after math 10.569311380386353
# elapsedsec after math 10.585419654846191
# elapsedsec after math 10.601306200027466
# elapsedsec after math 10.617170333862305
# elapsedsec after math 10.633075952529907
# elapsedsec after math 10.649211168289185
# elapsedsec after math 10.665328979492188
# elapsedsec after math 10.681480407714844
# elapsedsec after math 10.697744369506836
# elapsedsec after math 10.714613199234009
# elapsedsec after math 10.729893445968628
# elapsedsec after math 10.746379613876343
# elapsedsec after math 10.762436866760254
# elapsedsec after math 10.778707504272461
# elapsedsec after math 10.794936895370483
# elapsedsec after math 10.811123132705688
# elapsedsec after math 10.827423572540283
# elapsedsec after math 10.84336805343628
# elapsedsec after math 10.85925030708313
# elapsedsec after math 10.875043153762817
# elapsedsec after math 10.890991687774658
# elapsedsec after math 10.906760215759277
# elapsedsec after math 10.923612117767334
# elapsedsec after math 10.939410209655762
# elapsedsec after math 10.955180406570435
# elapsedsec after math 10.971068620681763
# elapsedsec after math 10.986990928649902
# elapsedsec after math 11.003380060195923
# elapsedsec after math 11.019109010696411
# elapsedsec after math 11.035018920898438
# elapsedsec after math 11.050900936126709
# elapsedsec after math 11.066817283630371
# elapsedsec after math 11.083705186843872
# elapsedsec after math 11.10037899017334
# elapsedsec after math 11.116079092025757
# elapsedsec after math 11.132292032241821
# elapsedsec after math 11.148374319076538
# elapsedsec after math 11.164633512496948
# elapsedsec after math 11.180991888046265
# elapsedsec after math 11.196602582931519
# elapsedsec after math 11.211751222610474
# elapsedsec after math 11.228665113449097
# elapsedsec after math 11.245630502700806
# myengine.pausedtime 3.814697265625e-05
# myengine.pausedtime 0.045049190521240234
# myengine.pausedtime 0.088958740234375
# myengine.pausedtime 0.1315145492553711
# myengine.pausedtime 0.17348694801330566
# myengine.pausedtime 0.21449685096740723
# myengine.pausedtime 0.2560293674468994
# myengine.pausedtime 0.3018777370452881
# myengine.pausedtime 0.34316468238830566
# myengine.pausedtime 0.3842737674713135
# myengine.pausedtime 0.4252164363861084
# myengine.pausedtime 0.46697306632995605
# myengine.pausedtime 0.5132918357849121
# myengine.pausedtime 0.5558342933654785
# myengine.pausedtime 0.5977246761322021
# myengine.pausedtime 0.6389772891998291
# myengine.pausedtime 0.6812570095062256
# myengine.pausedtime 0.7272965908050537
# myengine.pausedtime 0.769207239151001
# myengine.pausedtime 0.8105921745300293
# myengine.pausedtime 0.856043815612793
# myengine.pausedtime 0.9250695705413818
# myengine.pausedtime 0.9753761291503906
# myengine.pausedtime 1.0183477401733398
# myengine.pausedtime 1.0607445240020752
# myengine.pausedtime 1.103130578994751
# myengine.pausedtime 1.1489713191986084
# myengine.pausedtime 1.192845344543457
# myengine.pausedtime 1.2362127304077148
# myengine.pausedtime 1.2784130573272705
# elapsedsec after math 11.3065927028656
# elapsedsec after math 11.320739984512329
# elapsedsec after math 11.33678412437439
# elapsedsec after math 11.352806091308594
# elapsedsec after math 11.370995283126831
# elapsedsec after math 11.3852698802948
# elapsedsec after math 11.400983810424805
# elapsedsec after math 11.417131185531616
# elapsedsec after math 11.432419538497925
# elapsedsec after math 11.448783159255981
# elapsedsec after math 11.465230941772461
# elapsedsec after math 11.48056697845459
# elapsedsec after math 11.49654507637024
# elapsedsec after math 11.513301134109497
# elapsedsec after math 11.530234813690186
# elapsedsec after math 11.546033143997192
# elapsedsec after math 11.562151193618774
# elapsedsec after math 11.578517198562622
# elapsedsec after math 11.594289779663086
# elapsedsec after math 11.611084938049316
# elapsedsec after math 11.626994848251343
# elapsedsec after math 11.642818212509155
# elapsedsec after math 11.658848524093628
# elapsedsec after math 11.674742937088013
# elapsedsec after math 11.690820455551147
# elapsedsec after math 11.706619024276733
# elapsedsec after math 11.722528457641602
# elapsedsec after math 11.739315748214722
# elapsedsec after math 11.756599187850952
# elapsedsec after math 11.771546363830566
# elapsedsec after math 11.78817367553711
# elapsedsec after math 11.803415060043335
# elapsedsec after math 11.819664478302002
# elapsedsec after math 11.83558201789856
# elapsedsec after math 11.851797103881836
# myengine.pausedtime 4.0531158447265625e-05
# myengine.pausedtime 0.04304075241088867
# myengine.pausedtime 0.08547806739807129
# myengine.pausedtime 0.13436317443847656
# myengine.pausedtime 0.17681431770324707
# myengine.pausedtime 0.21838903427124023
# myengine.pausedtime 0.2599005699157715
# myengine.pausedtime 0.3011050224304199
# myengine.pausedtime 0.3429374694824219
# myengine.pausedtime 0.3898019790649414
# myengine.pausedtime 0.4312732219696045
# myengine.pausedtime 0.47219419479370117
# myengine.pausedtime 0.5134842395782471
# myengine.pausedtime 0.5546438694000244
# myengine.pausedtime 0.6016156673431396
# myengine.pausedtime 0.6423768997192383
# myengine.pausedtime 0.683673620223999
# myengine.pausedtime 0.7245726585388184
# elapsedsec after math 11.913483381271362
# elapsedsec after math 11.927661895751953
# elapsedsec after math 11.943355321884155
# elapsedsec after math 11.95902419090271
# elapsedsec after math 11.977269887924194
# elapsedsec after math 11.991276502609253
# elapsedsec after math 12.007131338119507
# elapsedsec after math 12.023074388504028
# elapsedsec after math 12.038903951644897
# elapsedsec after math 12.054822444915771
# elapsedsec after math 12.071626901626587
# elapsedsec after math 12.087610483169556
# elapsedsec after math 12.103461027145386
# elapsedsec after math 12.119573831558228
# elapsedsec after math 12.135413408279419
# elapsedsec after math 12.151622295379639
# elapsedsec after math 12.167466878890991
# elapsedsec after math 12.183402299880981
# elapsedsec after math 12.199353456497192
# elapsedsec after math 12.21561050415039
# elapsedsec after math 12.23080849647522
# elapsedsec after math 12.247285842895508
# elapsedsec after math 12.263484239578247
# elapsedsec after math 12.279701948165894
# elapsedsec after math 12.296534299850464
# elapsedsec after math 12.311850309371948
# elapsedsec after math 12.328201532363892
# elapsedsec after math 12.344258069992065
# elapsedsec after math 12.359933137893677
# elapsedsec after math 12.376777648925781
# elapsedsec after math 12.393620729446411
# elapsedsec after math 12.408940076828003
# elapsedsec after math 12.424850225448608
# elapsedsec after math 12.440774202346802
# elapsedsec after math 12.45768404006958
# elapsedsec after math 12.474491834640503
# elapsedsec after math 12.490317344665527
# elapsedsec after math 12.506630659103394
# elapsedsec after math 12.522430658340454
# elapsedsec after math 12.538271188735962
# elapsedsec after math 12.553830862045288
# elapsedsec after math 12.570518493652344
# myengine.pausedtime 5.054473876953125e-05
# myengine.pausedtime 0.042227983474731445
# myengine.pausedtime 0.08418679237365723
# myengine.pausedtime 0.12900614738464355
# myengine.pausedtime 0.18695712089538574
# myengine.pausedtime 0.23050689697265625
# myengine.pausedtime 0.2724273204803467
# myengine.pausedtime 0.31433868408203125
# elapsedsec after math 12.632219076156616
# elapsedsec after math 12.64560055732727
# elapsedsec after math 12.662074089050293
# elapsedsec after math 12.67823076248169
# elapsedsec after math 12.696380615234375
# elapsedsec after math 12.71012806892395
# elapsedsec after math 12.726272821426392
# elapsedsec after math 12.742294549942017
# elapsedsec after math 12.758080005645752
# elapsedsec after math 12.774007797241211
# elapsedsec after math 12.789921283721924
# elapsedsec after math 12.806081295013428
# elapsedsec after math 12.821982622146606
# elapsedsec after math 12.837830305099487
# elapsedsec after math 12.853665590286255
# elapsedsec after math 12.869471788406372
# elapsedsec after math 12.886253356933594
# elapsedsec after math 12.902276277542114
# elapsedsec after math 12.917933225631714
# elapsedsec after math 12.933643341064453
# elapsedsec after math 12.949517726898193
# elapsedsec after math 12.96642780303955
# elapsedsec after math 12.983355045318604
# elapsedsec after math 12.998797416687012
# elapsedsec after math 13.015169620513916
# elapsedsec after math 13.031147241592407
# elapsedsec after math 13.046971082687378
# elapsedsec after math 13.063218116760254
# elapsedsec after math 13.079545259475708
# elapsedsec after math 13.09491777420044
# elapsedsec after math 13.1110200881958
# elapsedsec after math 13.12695574760437
# elapsedsec after math 13.142889976501465
# elapsedsec after math 13.158807516098022
# elapsedsec after math 13.174793243408203
# elapsedsec after math 13.190775871276855
# elapsedsec after math 13.206898212432861
# elapsedsec after math 13.222880840301514
# elapsedsec after math 13.238870859146118
# elapsedsec after math 13.255167245864868
# elapsedsec after math 13.271083354949951
# elapsedsec after math 13.286985874176025
# elapsedsec after math 13.302813053131104
# elapsedsec after math 13.31872820854187
# elapsedsec after math 13.335346937179565
# elapsedsec after math 13.351542711257935
# elapsedsec after math 13.367503881454468
# elapsedsec after math 13.383570909500122
# elapsedsec after math 13.399789571762085
# elapsedsec after math 13.416088581085205
# elapsedsec after math 13.432671546936035
# elapsedsec after math 13.447771310806274
# elapsedsec after math 13.463892221450806
# elapsedsec after math 13.480101823806763
# elapsedsec after math 13.496014833450317
# elapsedsec after math 13.511871576309204
# elapsedsec after math 13.527954578399658
# elapsedsec after math 13.544095993041992
# elapsedsec after math 13.559967756271362
# elapsedsec after math 13.575879335403442
# elapsedsec after math 13.591988563537598
# elapsedsec after math 13.608113050460815
# elapsedsec after math 13.623810291290283
# elapsedsec after math 13.640253067016602
# elapsedsec after math 13.655832529067993
# elapsedsec after math 13.671871900558472
# elapsedsec after math 13.687864065170288
# elapsedsec after math 13.703909397125244
# elapsedsec after math 13.719722986221313
# elapsedsec after math 13.735576868057251
# elapsedsec after math 13.75239634513855
# elapsedsec after math 13.769332647323608
# elapsedsec after math 13.785695791244507
# elapsedsec after math 13.800565481185913
# elapsedsec after math 13.817411422729492
# elapsedsec after math 13.833546876907349
# elapsedsec after math 13.852445840835571
# elapsedsec after math 13.8686044216156
# elapsedsec after math 13.884244441986084
# elapsedsec after math 13.900560855865479
# elapsedsec after math 13.916905641555786
# elapsedsec after math 13.933104991912842
# elapsedsec after math 13.94927716255188
# elapsedsec after math 13.964932680130005
# elapsedsec after math 13.981054782867432
# elapsedsec after math 13.997182369232178
# elapsedsec after math 14.013232707977295
# elapsedsec after math 14.028587341308594
# elapsedsec after math 14.045405387878418
# elapsedsec after math 14.062078475952148
# elapsedsec after math 14.07812237739563
# elapsedsec after math 14.093939781188965
# elapsedsec after math 14.10973596572876
# elapsedsec after math 14.125531673431396
# elapsedsec after math 14.142601013183594
# elapsedsec after math 14.159359693527222
# elapsedsec after math 14.176271915435791
# elapsedsec after math 14.19211196899414
# elapsedsec after math 14.208114385604858
# elapsedsec after math 14.224255323410034
# elapsedsec after math 14.240171909332275
# elapsedsec after math 14.256047487258911
# elapsedsec after math 14.271974086761475
# elapsedsec after math 14.287733554840088
# elapsedsec after math 14.303587198257446
# elapsedsec after math 14.319874286651611
# elapsedsec after math 14.33584189414978
# elapsedsec after math 14.35181474685669
# elapsedsec after math 14.36745810508728
# elapsedsec after math 14.384326457977295
# elapsedsec after math 14.40007996559143
# elapsedsec after math 14.415951251983643
# elapsedsec after math 14.431683540344238
# elapsedsec after math 14.447533130645752
# elapsedsec after math 14.464299440383911
# elapsedsec after math 14.480147361755371
# elapsedsec after math 14.49626636505127
# elapsedsec after math 14.512130975723267
# elapsedsec after math 14.527906656265259
# elapsedsec after math 14.543789625167847
# elapsedsec after math 14.559518337249756
# elapsedsec after math 14.576196432113647
# elapsedsec after math 14.591840505599976
# elapsedsec after math 14.607779264450073
# elapsedsec after math 14.624046087265015
# elapsedsec after math 14.639964818954468
# elapsedsec after math 14.655951023101807
# elapsedsec after math 14.67225193977356
# elapsedsec after math 14.688013315200806
# elapsedsec after math 14.703945875167847
# elapsedsec after math 14.719791650772095
# elapsedsec after math 14.735716104507446
# elapsedsec after math 14.751582860946655
# elapsedsec after math 14.768356084823608
# elapsedsec after math 14.784996747970581
# elapsedsec after math 14.800953149795532
# elapsedsec after math 14.816845655441284
# elapsedsec after math 14.832936525344849
# elapsedsec after math 14.849515438079834
# elapsedsec after math 14.865400075912476
# elapsedsec after math 14.882237195968628
# elapsedsec after math 14.898064136505127
# elapsedsec after math 14.913883209228516
# elapsedsec after math 14.930016279220581
# elapsedsec after math 14.945849657058716
# elapsedsec after math 14.962153673171997
# elapsedsec after math 14.977455854415894
# elapsedsec after math 14.994375944137573
# elapsedsec after math 15.009713649749756
# elapsedsec after math 15.026002407073975
# elapsedsec after math 15.041609048843384
# elapsedsec after math 15.057488203048706
# elapsedsec after math 15.073754072189331
# elapsedsec after math 15.090199708938599
# elapsedsec after math 15.1055326461792
# elapsedsec after math 15.121630668640137
# elapsedsec after math 15.137521028518677
# elapsedsec after math 15.153508186340332
# elapsedsec after math 15.170334100723267
# elapsedsec after math 15.186318635940552
# elapsedsec after math 15.20262598991394
# elapsedsec after math 15.218875646591187
# elapsedsec after math 15.235028266906738
# elapsedsec after math 15.25089693069458
# elapsedsec after math 15.266773223876953
# elapsedsec after math 15.282745122909546
# elapsedsec after math 15.29882264137268
# elapsedsec after math 15.315090417861938
# elapsedsec after math 15.331133127212524
# elapsedsec after math 15.347257375717163
# elapsedsec after math 15.36320185661316
# elapsedsec after math 15.379791975021362
# elapsedsec after math 15.395646095275879
# elapsedsec after math 15.411868572235107
# elapsedsec after math 15.428040742874146
# elapsedsec after math 15.444182395935059
# elapsedsec after math 15.45964241027832
# elapsedsec after math 15.475462436676025
# elapsedsec after math 15.492294549942017
# elapsedsec after math 15.50813341140747
# elapsedsec after math 15.524085521697998
# elapsedsec after math 15.540024995803833
# elapsedsec after math 15.556220293045044
# elapsedsec after math 15.57216763496399
# elapsedsec after math 15.587984085083008
# elapsedsec after math 15.603781700134277
# elapsedsec after math 15.620450973510742
# elapsedsec after math 15.637176990509033
# elapsedsec after math 15.653029441833496
# elapsedsec after math 15.668797016143799
# elapsedsec after math 15.684588432312012
# elapsedsec after math 15.701403617858887
# elapsedsec after math 15.718226671218872
# elapsedsec after math 15.73442816734314
# elapsedsec after math 15.750339984893799
# elapsedsec after math 15.7672119140625
# elapsedsec after math 15.78336477279663
# elapsedsec after math 15.800425052642822
# elapsedsec after math 15.817183256149292
# elapsedsec after math 15.832517623901367
# elapsedsec after math 15.849122762680054
# elapsedsec after math 15.86490535736084
# elapsedsec after math 15.881137132644653
# elapsedsec after math 15.897228002548218
# elapsedsec after math 15.913362503051758
# elapsedsec after math 15.929374694824219
# elapsedsec after math 15.946182489395142
# elapsedsec after math 15.962056398391724
# elapsedsec after math 15.97780156135559
# elapsedsec after math 15.99367380142212
# elapsedsec after math 16.00952172279358
# elapsedsec after math 16.02635645866394
# elapsedsec after math 16.042962312698364
# elapsedsec after math 16.05888032913208
# elapsedsec after math 16.074893712997437
# elapsedsec after math 16.09085464477539
# elapsedsec after math 16.106861352920532
# elapsedsec after math 16.123021125793457
# elapsedsec after math 16.138983249664307
# elapsedsec after math 16.155057907104492
# elapsedsec after math 16.170791149139404
# elapsedsec after math 16.1865336894989
# elapsedsec after math 16.203441858291626
# elapsedsec after math 16.22026515007019
# elapsedsec after math 16.23610520362854
# elapsedsec after math 16.252257347106934
# elapsedsec after math 16.267839670181274
# elapsedsec after math 16.284364223480225
# elapsedsec after math 16.300527095794678
# elapsedsec after math 16.31685209274292
# elapsedsec after math 16.332879543304443
# elapsedsec after math 16.3487491607666
# elapsedsec after math 16.364546298980713
# elapsedsec after math 16.38056778907776
# elapsedsec after math 16.396543979644775
# elapsedsec after math 16.41252303123474
# elapsedsec after math 16.42936897277832
# elapsedsec after math 16.446726083755493
# elapsedsec after math 16.462682962417603
# elapsedsec after math 16.478715419769287
# elapsedsec after math 16.494601249694824
# elapsedsec after math 16.51078176498413
# elapsedsec after math 16.526845932006836
# elapsedsec after math 16.542725801467896
# elapsedsec after math 16.55869722366333
# elapsedsec after math 16.574631214141846
# elapsedsec after math 16.5905659198761
# elapsedsec after math 16.606566190719604
# elapsedsec after math 16.622929334640503
# elapsedsec after math 16.638872623443604
# elapsedsec after math 16.654893159866333
# elapsedsec after math 16.67054009437561
# elapsedsec after math 16.687209606170654
# elapsedsec after math 16.7032151222229
# elapsedsec after math 16.71847438812256
# elapsedsec after math 16.735333919525146
# elapsedsec after math 16.751226902008057
# elapsedsec after math 16.767125606536865
# elapsedsec after math 16.782965898513794
# elapsedsec after math 16.799103498458862
# elapsedsec after math 16.815070152282715
# elapsedsec after math 16.830945014953613
# elapsedsec after math 16.8468234539032
# elapsedsec after math 16.862730503082275
# elapsedsec after math 16.878741979599
# elapsedsec after math 16.89504837989807
# elapsedsec after math 16.911022424697876
# elapsedsec after math 16.927027225494385
# elapsedsec after math 16.942862272262573
# elapsedsec after math 16.958849668502808
# elapsedsec after math 16.975074529647827
# elapsedsec after math 16.99109435081482
# elapsedsec after math 17.00717806816101
# elapsedsec after math 17.02317523956299
# elapsedsec after math 17.038931369781494
# elapsedsec after math 17.05461549758911
# elapsedsec after math 17.071368932724
# elapsedsec after math 17.08760166168213
# elapsedsec after math 17.103487730026245
# elapsedsec after math 17.120180130004883
# elapsedsec after math 17.135945558547974
# elapsedsec after math 17.152361154556274
# elapsedsec after math 17.168136835098267
# elapsedsec after math 17.18424701690674
# elapsedsec after math 17.200043201446533
# elapsedsec after math 17.21589493751526
# elapsedsec after math 17.231606483459473
# elapsedsec after math 17.248395919799805
# elapsedsec after math 17.2652645111084
# elapsedsec after math 17.281243085861206
# elapsedsec after math 17.29704260826111
# elapsedsec after math 17.312758207321167
# elapsedsec after math 17.328937530517578
# elapsedsec after math 17.34458899497986
# elapsedsec after math 17.361392974853516
# elapsedsec after math 17.378422021865845
# elapsedsec after math 17.394564628601074
# elapsedsec after math 17.41055417060852
# elapsedsec after math 17.426499366760254
# elapsedsec after math 17.443437337875366
# elapsedsec after math 17.4602210521698
# elapsedsec after math 17.476090669631958
# elapsedsec after math 17.491926908493042
# elapsedsec after math 17.508203268051147
# elapsedsec after math 17.524017810821533
# elapsedsec after math 17.53956413269043
# elapsedsec after math 17.5562641620636
# elapsedsec after math 17.57204246520996
# elapsedsec after math 17.588055849075317
# elapsedsec after math 17.604241132736206
# elapsedsec after math 17.620036363601685
# elapsedsec after math 17.63593864440918
# elapsedsec after math 17.651718378067017
# elapsedsec after math 17.667591333389282
# elapsedsec after math 17.684715747833252
# elapsedsec after math 17.700425386428833
# elapsedsec after math 17.71704936027527
# elapsedsec after math 17.732821464538574
# elapsedsec after math 17.74863624572754
# elapsedsec after math 17.76453471183777
# elapsedsec after math 17.781118631362915
# elapsedsec after math 17.796888828277588
# elapsedsec after math 17.81254529953003
# elapsedsec after math 17.828545093536377
# elapsedsec after math 17.845279932022095
# elapsedsec after math 17.86147904396057
# elapsedsec after math 17.877208709716797
# elapsedsec after math 17.893072366714478
# elapsedsec after math 17.90897226333618
# elapsedsec after math 17.92503595352173
# elapsedsec after math 17.940987825393677
# elapsedsec after math 17.956942081451416
# elapsedsec after math 17.972724437713623
# elapsedsec after math 17.989376306533813
# elapsedsec after math 18.006059646606445
# elapsedsec after math 18.02223300933838
# elapsedsec after math 18.037339448928833
# elapsedsec after math 18.053189992904663
# elapsedsec after math 18.06924080848694
# elapsedsec after math 18.08511972427368
# elapsedsec after math 18.10099768638611
# elapsedsec after math 18.121233701705933
# elapsedsec after math 18.137298583984375
# elapsedsec after math 18.1542387008667
# elapsedsec after math 18.171521186828613
# elapsedsec after math 18.18565583229065
# elapsedsec after math 18.201473236083984
# elapsedsec after math 18.220099210739136
# elapsedsec after math 18.23534893989563
# elapsedsec after math 18.252179622650146
# elapsedsec after math 18.268146514892578
# elapsedsec after math 18.28432559967041
# elapsedsec after math 18.300394296646118
# elapsedsec after math 18.317330360412598
# elapsedsec after math 18.333242654800415
# elapsedsec after math 18.34891366958618
# elapsedsec after math 18.365764379501343
# elapsedsec after math 18.38187575340271
# elapsedsec after math 18.398460149765015
# elapsedsec after math 18.413864374160767
# elapsedsec after math 18.429826498031616
# elapsedsec after math 18.44595956802368
# elapsedsec after math 18.46190905570984
# elapsedsec after math 18.477739810943604
# elapsedsec after math 18.49357533454895
# elapsedsec after math 18.50949740409851
# elapsedsec after math 18.52572202682495
# elapsedsec after math 18.541718006134033
# elapsedsec after math 18.55796241760254
# elapsedsec after math 18.574434518814087
# elapsedsec after math 18.590272665023804
# elapsedsec after math 18.606115341186523
# elapsedsec after math 18.62211561203003
# elapsedsec after math 18.637853384017944
# elapsedsec after math 18.65380096435547
# elapsedsec after math 18.66961169242859
# elapsedsec after math 18.68548893928528
# elapsedsec after math 18.702281951904297
# elapsedsec after math 18.717851161956787
# elapsedsec after math 18.73436164855957
# elapsedsec after math 18.75053119659424
# elapsedsec after math 18.765719890594482
# elapsedsec after math 18.781756162643433
# elapsedsec after math 18.797868251800537
# elapsedsec after math 18.813820838928223
# elapsedsec after math 18.829740285873413
# elapsedsec after math 18.84559416770935
# elapsedsec after math 18.86240291595459
# elapsedsec after math 18.879199028015137
# elapsedsec after math 18.895080089569092
# elapsedsec after math 18.911104440689087
# elapsedsec after math 18.92737889289856
# elapsedsec after math 18.943164587020874
# elapsedsec after math 18.959147214889526
# elapsedsec after math 18.975160837173462
# elapsedsec after math 18.99063491821289
# elapsedsec after math 19.0068199634552
# elapsedsec after math 19.022530794143677
# elapsedsec after math 19.03750228881836
# elapsedsec after math 19.05434536933899
# elapsedsec after math 19.071187257766724
# elapsedsec after math 19.087316513061523
# elapsedsec after math 19.103414058685303
# elapsedsec after math 19.119152784347534
# elapsedsec after math 19.134906768798828
# elapsedsec after math 19.150704383850098
# elapsedsec after math 19.167398929595947
# elapsedsec after math 19.183465003967285
# elapsedsec after math 19.199768781661987
# elapsedsec after math 19.216059684753418
# elapsedsec after math 19.231467723846436
# elapsedsec after math 19.248042821884155
# elapsedsec after math 19.264403104782104
# elapsedsec after math 19.281519412994385
# elapsedsec after math 19.297393560409546
# elapsedsec after math 19.31438946723938
# elapsedsec after math 19.331112146377563
# elapsedsec after math 19.346996545791626
# elapsedsec after math 19.362770557403564
# elapsedsec after math 19.379353284835815
# elapsedsec after math 19.394516706466675
# elapsedsec after math 19.411093711853027
# elapsedsec after math 19.427350521087646
# elapsedsec after math 19.44342589378357
# elapsedsec after math 19.46076488494873
# elapsedsec after math 19.4769024848938
# elapsedsec after math 19.49308681488037
# elapsedsec after math 19.509047985076904
# elapsedsec after math 19.524990797042847
# elapsedsec after math 19.54117202758789
# elapsedsec after math 19.557072401046753
# elapsedsec after math 19.573180437088013
# elapsedsec after math 19.588984966278076
# elapsedsec after math 19.6049485206604
# elapsedsec after math 19.621023654937744
# elapsedsec after math 19.637484550476074
# elapsedsec after math 19.652450561523438
# elapsedsec after math 19.66944456100464
# elapsedsec after math 19.68625235557556
# elapsedsec after math 19.70207452774048
# elapsedsec after math 19.717856645584106
# elapsedsec after math 19.733659744262695
# elapsedsec after math 19.749478578567505
# elapsedsec after math 19.765774488449097
# elapsedsec after math 19.78163766860962
# elapsedsec after math 19.7975115776062
# elapsedsec after math 19.814321279525757
# elapsedsec after math 19.829612731933594
# elapsedsec after math 19.846027851104736
# elapsedsec after math 19.862261056900024
# elapsedsec after math 19.878000736236572
# elapsedsec after math 19.893790006637573
# elapsedsec after math 19.90971302986145
# elapsedsec after math 19.925750017166138
# elapsedsec after math 19.941704511642456
# elapsedsec after math 19.957972526550293
# elapsedsec after math 19.97384810447693
# elapsedsec after math 19.990288257598877
# elapsedsec after math 20.00625967979431
# elapsedsec after math 20.02241039276123
# elapsedsec after math 20.03865957260132
# elapsedsec after math 20.05470895767212
# elapsedsec after math 20.07047748565674
# elapsedsec after math 20.08697819709778
# elapsedsec after math 20.103100299835205
# elapsedsec after math 20.119398593902588
# elapsedsec after math 20.136374711990356
# elapsedsec after math 20.1521999835968
# elapsedsec after math 20.168380737304688
# elapsedsec after math 20.184139013290405
# elapsedsec after math 20.200000047683716
# elapsedsec after math 20.21605920791626
# elapsedsec after math 20.232571363449097
# elapsedsec after math 20.249213457107544
# elapsedsec after math 20.264759302139282
# elapsedsec after math 20.280531406402588
# elapsedsec after math 20.29656457901001
# elapsedsec after math 20.312439441680908
# elapsedsec after math 20.329230546951294
# elapsedsec after math 20.34539794921875
# elapsedsec after math 20.361124753952026
# elapsedsec after math 20.377036094665527
# elapsedsec after math 20.39305281639099
# elapsedsec after math 20.40902543067932
