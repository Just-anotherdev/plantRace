# %%
import random
import pygame
import numpy as np
from PIL import Image
import time
import base64
import re


class Engine:
    def __init__(self):
        pygame.init()  # initialize pygame
        pygame.font.init()  # initialize fonts
        self.basefont = pygame.font.SysFont("Comic Sans MS", 30)  # finish initializing font
        self.stopwatch = stopwatch()
        self.stopwatch.update()
        self.scoreboard = scoreboard()
        self.init_groups()
        self.init_screen()
        self.poodissapear = 1
        self.food = 0
        self.score = 0
        self.clock = pygame.time.Clock()
        self.resetiter = 0
        self.animationtimer = 0
        self.growtimer = 0
        self.winner = 0
        self.starttime = time.time()
        self.showcontrols = 1
        self.winscore = 0
        self.haspooped = 0
        self.mode = 0
        self.itt = interactivetextbox()
        self.stringbuffer = []

    def init_score(self):
        self.score = 0
        self.winscore = 0
        self.mapscore = 0
        for sprite in self.tileset:
            if sprite.tilename == "plant1stage3wet":
                self.mapscore = self.mapscore + 1
        for sprite in self.tileset:
            if (
                sprite.tilename == "plant1stage1wet"
                or sprite.tilename == "plant1stage2wet"
                or sprite.tilename == "dirtwet"
            ):
                self.winscore = self.winscore + 1

    def test_win(self):
        if self.score >= self.winscore:
            self.winner = 1
            self.scoreboard.write(self.stopwatch.elapsedsec)
        if self.winner == 1:
            for sprite in self.poopobj:
                sprite.image = pygame.image.load("Assets/sprites/goldpoop.png")
            for sprite in self.fishobj:
                sprite.kill()
            self.food = 5000
            self.poodissapear = 0
            self.mode = 5
    def init_screen(self):
        self.windowh = 640
        self.windoww = 960
        self.screen = pygame.display.set_mode((self.windoww, self.windowh))

    def init_groups(self):
        self.poopobj = pygame.sprite.Group()  # all poops
        self.fishobj = pygame.sprite.Group()  # all fish
        self.tileset = pygame.sprite.Group()  # all tiles
        self.allvisible = pygame.sprite.Group()  # all visible sprites
        self.watertiles = pygame.sprite.Group()  # all watertiles
        self.toanimate = pygame.sprite.Group()

    def render_screen(self):
        
        if self.mode == 0:
            splashscreen = pygame.image.load(f"{self.splashprefix}startscreen.png")
            self.screen.blit(splashscreen, (0,0))
        elif self.mode == 1:
            splashscreen = pygame.image.load(f"{self.splashprefix}entername.png")
            self.screen.blit(splashscreen, (0,0))
            self.render_hud()
        elif self.mode == 2:
            splashscreen = pygame.image.load(f"{self.splashprefix}controls.png")
            self.screen.blit(splashscreen,(0,0))
        elif self.mode == 3:
            
            #game running
            for sprite in self.allvisible:
                
                self.screen.blit(
                    sprite.image,
                    (sprite.rect.x - cameraobj.rect.x, sprite.rect.y - cameraobj.rect.y),
                )
                
            self.render_hud()
        elif self.mode == 4:
            splashscreen = pygame.image.load(f"{self.splashprefix}pause.png")
            self.screen.blit(splashscreen,(0,0))
            pass
        elif self.mode == 5:
            splashscreen = pygame.image.load(f"{self.splashprefix}winscreen.png")
            self.screen.blit(splashscreen, (0,0))
            self.render_hud()
            #game won
            pass
        
        pygame.display.flip()
        
        
    def render_hud(self):
        if self.mode == 1:
            self.itt.render()
        elif self.mode == 3:
            if self.showcontrols == 1:
                controlmessage = self.basefont.render("use the arrow keys or wasd to move", False, (255, 255, 255))
                self.screen.blit(controlmessage, ((self.windoww / 2) - 200, (self.windowh / 2) - 200))
            elif self.showcontrols == 0 and self.food < 2 and self.score < self.winscore:
                hungermes = self.basefont.render("you feel hungry", False, (255, 255, 255))
                self.screen.blit(hungermes, ((self.windoww / 2) - 100, (self.windowh / 2) - 200))
            elif self.showcontrols == 0 and self.food == 100 and self.score < self.winscore:
                fullmesg = self.basefont.render("you feel full", False, (255, 255, 255))
                self.screen.blit(fullmesg, ((self.windoww / 2) - 80, (self.windowh / 2) - 200))
            elif self.showcontrols == 0 and self.food > 2 and self.haspooped == 0:
                poomesg = self.basefont.render("use spacebar to poop. plants need poop to grow", False, (255, 255, 255))
                self.screen.blit(poomesg, ((self.windoww / 2) - 250, (self.windowh / 2) - 200))
            elif self.showcontrols == 0 and self.haspooped == 1:
                scoremesg = self.basefont.render(f"SCORE: {self.score}  /  {self.winscore}", False, (255, 255, 255))
                self.screen.blit(scoremesg, ((self.windoww / 2) - 58, (self.windowh / 10)))
            stopwatchmesg = self.basefont.render(self.stopwatch.stopwatchmesg, False, (255, 255, 255))
            self.screen.blit(stopwatchmesg, (50, ((self.windowh / 10) * 9)))
        elif self.mode == 5:
            if self.winner == 1:
                winmessage = self.basefont.render("you win! thanks for playing my tech demo!", False, (255, 255, 255))
                self.screen.blit(winmessage, ((self.windoww / 2) - 180, self.windowh / 2 - 220))
                self.scoreboard.build()
                
                if len(self.scoreboard.top10) >= 1:
                    self.screen.blit(self.scoreboard.mesg, (((self.windoww /2) - 50), self.windowh / 2 - 180))
                    self.screen.blit(self.scoreboard.first, (((self.windoww / 2) - 145), self.windowh / 2 - 160))
                if len(self.scoreboard.top10) >= 2:
                    self.screen.blit(self.scoreboard.second, (((self.windoww / 2) - 145), self.windowh / 2 - 140))
                if len(self.scoreboard.top10) >= 3:
                    self.screen.blit(self.scoreboard.third, (((self.windoww / 2) - 145), self.windowh / 2 - 120))
                if len(self.scoreboard.top10) >= 4:
                    self.screen.blit(self.scoreboard.fourth, (((self.windoww / 2) - 145), self.windowh / 2 - 100))
                if len(self.scoreboard.top10) >= 5:
                    self.screen.blit(self.scoreboard.fifth, (((self.windoww / 2) - 145), self.windowh / 2 - 80))
                if len(self.scoreboard.top10) >= 6:
                    self.screen.blit(self.scoreboard.sixth, (((self.windoww / 2) - 145), self.windowh / 2 - 60))
                if len(self.scoreboard.top10) >= 7:
                    self.screen.blit(self.scoreboard.seventh, (((self.windoww / 2) - 145), self.windowh / 2 - 40))
                if len(self.scoreboard.top10) >= 8:
                    self.screen.blit(self.scoreboard.eigth, (((self.windoww / 2) - 145), self.windowh / 2 - 20))
                if len(self.scoreboard.top10) >= 9:
                    self.screen.blit(self.scoreboard.ninth, (((self.windoww / 2) - 145), self.windowh / 2))
                if len(self.scoreboard.top10) >= 10:
                    self.screen.blit(self.scoreboard.tenth, ((((self.windoww / 2) - 145), ((self.windowh / 2) + 20))))
            

    def update_logic(self):
        
        if self.mode == 0:
            #title screen
            pass
        elif self.mode == 1:
            #enter name
            self.itt.update()
            pass
        elif self.mode == 2:
            #show controls
            pass
        elif self.mode == 3:
            
            self.normalize_velocity()
            
            self.update_fish()
            
            mycat.update()
            
            self.poopobj.update()
            
            self.animate_all()
            
            cameraobj.update()
            
            self.lock_in_bounds()
            
            self.calculate_score()
            
            self.test_win()
            
            self.grow_plants()
            
            if self.winner == 0:
                self.stopwatch.update()
                
        elif self.mode == 4:
            #
            #
            self.stopwatch.update()
            #
            pass
        elif self.mode == 5:
            #won
            pass
        
    def animate_all(self):
        self.animationtimer = self.animationtimer + 1
        if self.animationtimer > 10:
            self.animationtimer = 0
            for sprite in self.toanimate:
                sprite.animate()

    def test_keys(self):
        
        if self.mode == 0:
            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_SPACE:
                        self.mode = 1
                if event.type == pygame.QUIT:
                    pygame.quit()
                    quit()
        elif self.mode == 1:
            #enter name
            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_RETURN:
                        self.playername = "".join(self.stringbuffer)
                        self.stringbuffer = []
                        self.mode = 2
                    elif event.key == pygame.K_BACKSPACE:
                        if len(self.stringbuffer) >= 1:
                            self.stringbuffer.pop()
                    else:
                        self.stringbuffer.append(event.unicode)
                if event.type == pygame.QUIT:
                    pygame.quit()
                    quit()
        elif self.mode == 2:
            #show controls
            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_SPACE:
                        self.stopwatch.reset()
                        self.mode = 3
                        
                if event.type == pygame.QUIT:
                    pygame.quit()
                    quit()
        elif self.mode == 3:
            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_u:
                        mycat.catcolor = 0
                        
                    if event.key == pygame.K_i:
                        mycat.catcolor = 1
                    if event.key == pygame.K_o:
                        mycat.catcolor = 2
                    if event.key == pygame.K_q:
                        self.winner = 1
                        self.scoreboard.write(self.stopwatch.elapsedsec)
                    if event.key == pygame.K_LEFT or event.key == pygame.K_a:
                        mycat.xv = -10
                        self.showcontrols = 0
                    elif event.key == pygame.K_RIGHT or event.key == pygame.K_d:
                        mycat.xv = 10
                        self.showcontrols = 0
                    elif event.key == pygame.K_UP or event.key == pygame.K_w:
                        mycat.yv = -10
                        self.showcontrols = 0
                    elif event.key == pygame.K_DOWN or event.key == pygame.K_s:
                        mycat.yv = 10
                        self.showcontrols = 0
                    if event.key == 27:  # escape
                        self.mode = 4
                        self.stopwatch.pause()
                        
                    elif event.key == 32:  # spacebar
                        if self.food > 0:
                            self.food = self.food - 1
                            if len(self.poopobj) < 10:
                                Poop(mycat.rect.left, mycat.rect.top)
                            else:
                                j = 0
                                tempi = 0
                                while tempi < 10:
                                    tempi = tempi + 1
                                    for e in self.poopobj:
                                        j = j + 1
                                        if j == 1:
                                            if self.poodissapear == 1:
                                                e.kill()
                                            Poop(mycat.rect.left, mycat.rect.top)
                if event.type == pygame.KEYUP:
                    if event.key == pygame.K_LEFT or event.key == pygame.K_a:
                        mycat.resetx = 1
                    elif event.key == pygame.K_RIGHT or event.key == pygame.K_d:
                        mycat.resetx = 1
                    elif event.key == pygame.K_UP or event.key == pygame.K_w:
                        mycat.resety = 1
                    elif event.key == pygame.K_DOWN or event.key == pygame.K_s:
                        mycat.resety = 1
                if event.type == pygame.QUIT:
                    pygame.quit()
                    quit()
        if self.mode == 4:
                for event in pygame.event.get():
                    if event.type == pygame.KEYDOWN:
                        if event.key == 27:
                            self.mode = 3
                            self.stopwatch.unpause()
                    if event.type == pygame.QUIT:
                        pygame.quit()
                        quit()
        if self.mode == 5:
                for event in pygame.event.get():
                    if event.type == pygame.QUIT:
                        pygame.quit()
                        quit()

    def update_fish(self):
        if len(self.fishobj) < len(self.watertiles) * 2:
            for sprite in self.tileset:
                sprite.populate_fish()
        for e in self.fishobj:
            if e.rect.colliderect(mycat.rect) == True:
                if self.food < 100:
                    self.food = self.food + 1
                    e.kill()

    def calculate_score(self):
        self.score = 0
        for sprite in self.tileset:
            if sprite.tilename == "plant1stage3wet":
                self.score = self.score + 1
        self.score = self.score - self.mapscore

    def normalize_velocity(self):
        if mycat.xv > 10:
            mycat.xv = 10
        if mycat.yv > 10:
            mycat.yv = 10
        if mycat.xv < -10:
            mycat.xv = -10
        if mycat.yv < -10:
            mycat.yv = -10
        self.resetiter = self.resetiter + 1
        if self.resetiter > 5:
            self.resetiter = 0
            if mycat.resetx == 1:
                mycat.xv = 0
                mycat.resetx = 0
            if mycat.resety == 1:
                mycat.yv = 0
                mycat.resety = 0
            mycat.resetx = 0
            mycat.resety = 0

    def grow_plants(self):
        self.growtimer = self.growtimer + 1
        if self.growtimer > 60:
            self.growtimer = 0
            for sprite in self.tileset:
                sprite.grow()

    def lock_in_bounds(self):
        mycat.rect.clamp_ip(self.bgframe.rect)
        cameraobj.rect.clamp_ip(self.bgframe.rect)


class Camera(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.rect = pygame.Rect(0, 0, myengine.windoww, myengine.windowh)
        self.update()

    def update(self):
        self.rect.centerx, self.rect.centery = mycat.rect.centerx, mycat.rect.centery


class interactivetextbox(pygame.sprite.Sprite):
    def __init__(self):
        pass
    def render(self):
        myengine.screen.blit(self.image,self.rect)
    def update(self):
        self.image = myengine.basefont.render("".join(myengine.stringbuffer), False , (255, 255, 255))
        self.rect = self.image.get_rect()
        self.rect.center = (myengine.windoww / 2, myengine.windowh / 2)
        pass

class Background(Engine):
    def __init__(self):
        super().__init__()
        self.tileprefix = "Assets/tiles/"  # prefix for tile filenames
        self.mapprefix = "Assets/maps/"  # prefix for input map filenames
        self.splashprefix = "Assets/splashscreens/"
        self.generate_bg()

    def init_bg_frame(self):
        self.bgframe = Bgframe()

    def init_tiles(self, tilename=("finishinit"), x=0, y=0):
        # this function initializes the tileset with the proper states based on tilename
        assert (
            type(tilename) is str
        ), "check input to inittiles tilename must be a string"
        assert (
            type(x) is int and type(y) is int
        ), "check input to inittiles x and y must be positive ints"
        assert (
            x >= 0 and y >= 0
        ), "check input to inittiles x and y must be positive ints"
        if tilename == "catbeddry":
            Tile("catbeddry", f"{self.tileprefix}catbeddry.png", x, y, self)
        elif tilename == "catbedwet":
            Tile("catbedwet", f"{self.tileprefix}catbedwet.png", x, y, self)
        elif tilename == "dirtdry":
            Tile("dirtdry", f"{self.tileprefix}dirtdry.png", x, y, self)
        elif tilename == "dirtuntilled":
            Tile("dirtuntilled", f"{self.tileprefix}dirtuntilled.png", x, y, self)
        elif tilename == "dirtwet":
            Tile("dirtwet", f"{self.tileprefix}dirtwet.png", x, y, self)
        elif tilename == "grass1":
            Tile("grass1", f"{self.tileprefix}grass1.png", x, y, self)
        elif tilename == "plant1stage1dry":
            Tile("plant1stage1dry", f"{self.tileprefix}plant1stage1dry.png", x, y, self)
        elif tilename == "plant1stage1wet":
            Tile("plant1stage1wet", f"{self.tileprefix}plant1stage1wet.png", x, y, self)
        elif tilename == "plant1stage2dry":
            Tile("plant1stage2dry", f"{self.tileprefix}plant1stage2dry.png", x, y, self)
        elif tilename == "plant1stage2wet":
            Tile("plant1stage2wet", f"{self.tileprefix}plant1stage2wet.png", x, y, self)
        elif tilename == "plant1stage3dry":
            Tile("plant1stage3dry", f"{self.tileprefix}plant1stage3dry.png", x, y, self)
        elif tilename == "plant1stage3wet":
            Tile("plant1stage3wet", f"{self.tileprefix}plant1stage3wet.png", x, y, self)
        elif tilename == "water":
            Tile("water", f"{self.tileprefix}water.png", x, y, self)
        else:
            pass

    def map_to_tiles(self, mapname):
        mappath = f"{self.mapprefix}{mapname}.png"
        conversiondict = {  # dictionary of tuples of rgb values as keys for tile names
            (np.uint8(229), np.uint8(45), np.uint8(255)): "catbeddry",
            (np.uint8(183), np.uint8(4), np.uint8(134)): "catbedwet",
            (np.uint8(241), np.uint8(240), np.uint8(92)): "dirtdry",
            (np.uint8(202), np.uint8(195), np.uint8(67)): "dirtuntilled",
            (np.uint8(74), np.uint8(41), np.uint8(0)): "dirtwet",
            (np.uint8(32), np.uint8(254), np.uint8(0)): "grass1",
            (np.uint8(224), np.uint8(166), np.uint8(41)): "plant1stage1dry",
            (np.uint8(227), np.uint8(243), np.uint8(0)): "plant1stage1wet",
            (np.uint8(255), np.uint8(198), np.uint8(45)): "plant1stage2dry",
            (np.uint8(212), np.uint8(255), np.uint8(0)): "plant1stage2wet",
            (np.uint8(255), np.uint8(174), np.uint8(0)): "plant1stage3dry",
            (np.uint8(255), np.uint8(253), np.uint8(0)): "plant1stage3wet",
            (np.uint8(0), np.uint8(36), np.uint8(254)): "water",
        }
        img = Image.open(mappath)  # import image as a pillow image
        img = img.convert("RGB")  # drop alpha
        img = np.asarray(img)  # import picture as numpy array
        inputw = img.shape[1]  # set inputw to the width of the input image
        inputh = img.shape[0]  # set inputh to the height of the input image
        p = 0
        tiles = []  # initialize
        temparray = []  # initialize a temporary array to pop from
        rgbvalues = []  # flat array of tuples representing rgb values
        for (
            m
        ) in (
            img
        ):  # loop through the 3d numpy array to extract an 1d array of tuples of rgb values
            for n in m:
                for o in n:
                    if p < 3:
                        p = p + 1
                        temparray.append(o)
                    else:
                        p = 1
                        rgbvalues.append(tuple(temparray))
                        temparray = []
                        temparray.append(o)
        rgbvalues.append(tuple(temparray))
        temparray = []
        for x in rgbvalues:  # convert the array to an array of tile file names
            tiles.append(conversiondict[x])
        return (tiles, inputh, inputw)

    def tiles_to_full_map(self, listoftiles, numofrows, numofcols):
        assert len(listoftiles) + 1 != int(numofrows) * int(
            numofcols
        ), "the list passed to tilestofullmap would not generate a valid map"
        tilewidth = 200  # the width in pixels of the tiles
        tileheight = 200  # the width in pixels of the tiles
        j = 1
        witer = 0
        hiter = 0
        bgwidth = numofcols * tilewidth
        bgheight = numofrows * tileheight
        iterlist = [0] * len(listoftiles)
        for e in iterlist:
            if j < numofcols:
                self.init_tiles(listoftiles.pop(0), witer, hiter)
                witer = witer + tilewidth
            else:
                self.init_tiles(listoftiles.pop(0), witer, hiter)
                witer = 0
                j = 0
                hiter = hiter + tileheight
            j = j + 1
        self.bgwidth, self.bgheight = bgwidth, bgheight

    def generate_bg(self):
        catchreturn1 = self.map_to_tiles("microdemo")
        self.tiles_to_full_map(catchreturn1[0], catchreturn1[1], catchreturn1[2])


class Tile(pygame.sprite.Sprite, Background):
    def __init__(self, tilename, image_file, posx, posy, engine):
        assert type(tilename) is str, "tilename must be a string"
        assert (
            type(posx) is int and type(posy) is int and posx >= 0 and posy >= 0
        ), "posx and posy must be positivve ints"
        self.tilename = tilename
        pygame.sprite.Sprite.__init__(self)  # call Sprite initializer
        self.image = pygame.image.load(image_file)  # load the tile image by name
        self.image = self.image.convert()
        self.rect = self.image.get_rect()  # prebaked rect from image
        self.rect.left, self.rect.top = (
            posx,
            posy,
        )  # takes in arguments to set position of rect
        tilename = tilename  # defines tilename
        engine.allvisible.add(self)  # adds to visible objects
        engine.tileset.add(self)
        if self.tilename == "water":  # adds to the group of water tiles if it is one
            engine.watertiles.add(self)

    def grow(self):
        # grows all plants that are wet and have [poop on them]
        if self.tilename == "plant1stage1wet":
            if pygame.sprite.spritecollideany(self, myengine.poopobj) is not None:
                self.tilename = "plant1stage2wet"
                self.image = pygame.image.load(
                    f"{myengine.tileprefix}plant1stage2wet.png"
                )
                self.image = self.image.convert()
                pooptokill = pygame.sprite.spritecollideany(self, myengine.poopobj)
                pooptokill.used = 1
        elif self.tilename == "plant1stage2wet":
            if pygame.sprite.spritecollideany(self, myengine.poopobj) is not None:
                self.tilename = "plant1stage3wet"
                self.image = pygame.image.load(
                    f"{myengine.tileprefix}plant1stage3wet.png"
                )
                self.image = self.image.convert()
                pooptokill = pygame.sprite.spritecollideany(self, myengine.poopobj)
                pooptokill.used = 1
        elif self.tilename == "dirtwet":
            if pygame.sprite.spritecollideany(self, myengine.poopobj) is not None:
                self.tilename = "plant1stage1wet"
                self.image = pygame.image.load(
                    f"{myengine.tileprefix}plant1stage1wet.png"
                )
                self.image = self.image.convert()
                pooptokill = pygame.sprite.spritecollideany(self, myengine.poopobj)
                pooptokill.used = 1

    def populate_fish(self):
        if self.tilename == "water":
            fish(
                random.randrange(
                    self.rect.left, (self.rect.left + self.rect.width) - 32
                ),
                random.randrange(self.rect.top, (self.rect.top + self.rect.width) - 32),
            )


class Bgframe(pygame.sprite.Sprite):
    # makes a rect around the background for collision detection
    def __init__(self):
        assert (
            type(myengine.bgwidth) is int and type(myengine.bgheight) is int
        ), "Bgframe requires bgheight and bgwidth to be non zero positive ints"
        assert (
            myengine.bgwidth > 0 and myengine.bgheight > 0
        ), "Bgframe requires bgheight and bgwidth to be non zero positive ints"
        pygame.sprite.Sprite.__init__(self)
        self.rect = pygame.Rect(0, 0, myengine.bgwidth, myengine.bgheight)

class scoreboard:
    def __init__(self):
        with open("Assets/saves/sb.scoreboard", "r") as scoreboard:
            scoreboard_b64_list = scoreboard.readlines()
            unsortedScoreboard = []
            for i in scoreboard_b64_list:
                unsortedScoreboard.append(base64.standard_b64decode(i).decode())
            self.unsortedscoreboard = unsortedScoreboard
            self.sortedscoreboard = sorted(
                unsortedScoreboard, key=lambda test_string: list(map(int, re.findall(r"\d+", test_string)))[0]
            )
            self.top10 = []
            i = 0
            for score in self.sortedscoreboard:
                if i <= 9:
                    self.top10.append(score)
                    i = i + 1

    def write(self, timelapsed):
        winning_stopwatch = f"{myengine.playername}  {myengine.stopwatch.elapsedsec:.2f} seconds"
        winning_stopwatch = winning_stopwatch.encode("utf-8")
        with open("Assets/saves/sb.scoreboard", "a") as scoreboard:
            b64winning_stopwatch = base64.standard_b64encode(winning_stopwatch)
            scoreboard.write(b64winning_stopwatch.decode())
            scoreboard.write("\n")
        with open("Assets/saves/sb.scoreboard", "r") as scoreboard:
            scoreboard_b64_list = scoreboard.readlines()
            unsortedScoreboard = []
            for i in scoreboard_b64_list:
                unsortedScoreboard.append(base64.standard_b64decode(i).decode())
            self.unsortedscoreboard = unsortedScoreboard
            self.sortedscoreboard = sorted(
                unsortedScoreboard, key=lambda test_string: list(map(int, re.findall(r"\d+", test_string)))[0]
            )
            self.top10 = []
            i = 0
            for score in self.sortedscoreboard:
                if i <= 9:
                    self.top10.append(score)
                    i = i + 1
                    
    def build(self):
        if len(self.top10) >= 10:
            self.tenth = myengine.basefont.render(f"10). {self.top10[9]}", False, (255, 255, 255))
        if len(self.top10) >= 9:
            self.ninth = myengine.basefont.render(f"9). {self.top10[8]}", False, (255, 255, 255))
        if len(self.top10) >= 8:
            self.eigth = myengine.basefont.render(f"8). {self.top10[7]}", False, (255, 255, 255))
        if len(self.top10) >= 7:
            self.seventh = myengine.basefont.render(f"7). {self.top10[6]}", False, (255, 255, 255))
        if len(self.top10) >= 6:
            self.sixth = myengine.basefont.render(f"6). {self.top10[5]}", False, (255, 255, 255))
        if len(self.top10) >= 5:
            self.fifth = myengine.basefont.render(f"5). {self.top10[4]}", False, (255, 255, 255))
        if len(self.top10) >= 4:
            self.fourth = myengine.basefont.render(f"4). {self.top10[3]}", False, (255, 255, 255))
        if len(self.top10) >= 3:
            self.third = myengine.basefont.render(f"3). {self.top10[2]}", False, (255, 255, 255))
        if len(self.top10) >= 2:
            self.second = myengine.basefont.render(f"2). {self.top10[1]}", False, (255, 255, 255))
        if len(self.top10) >= 1:
            self.mesg = myengine.basefont.render("SCOREBOARD", False, (255,255,255))
            self.first = myengine.basefont.render(f"1). {self.top10[0]}", False, (255, 255, 255))




class Player(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)  # initialize sprite
        self.catcolor = 0 # 0 for gray 1 for black 2 for brown
        self.catprefix = "Assets/sprites/cat/grayCat/"
        self.image = pygame.transform.scale2x(
            pygame.image. load(f"{self.catprefix}catstand1.png")
        )  # initialize the image of the cat stationary
        self.image = self.image.convert_alpha()
        self.rect = self.image.get_rect()
        self.rect.update(
            (myengine.windoww / 2) - 30, (myengine.windowh / 2) - 30, 100, 100
        )
        self.animiter = 0
        myengine.allvisible.add(self)
        myengine.toanimate.add(self)
        
        self.xv = 0
        self.yv = 0
        self.resetx = 0
        self.resety = 0
        
    
    def update(self):
        self.rect.move_ip(self.xv, self.yv)

    def animate(self):
        if self.catcolor == 0:
            self.catprefix = "Assets/sprites/cat/grayCat/"
        elif self.catcolor == 1:
            self.catprefix = "Assets/sprites/cat/blackCat/"
        elif self.catcolor == 2:
            self.catprefix = "Assets/sprites/cat/brownCat/" 
        else:
            self.catcolor = 0
            self.catprefix = "Assets/sprites/cat/grayCat"
        self.animiter = self.animiter + 1
        self.left = 0
        self.right = 0
        self.down = 0
        self.up = 0
        self.idle = 0
# this section of logic determines which way the cat should face favoring left and right over up and down
        if self.xv >= 1:
            self.right = 1  
        if self.yv >= 1:
            self.down = 1
        if self.xv < 0:
            self.left = 1
        if self.yv < 0:
            self.up = 1
        if self.right == 1:
            self.up = 0
            self.down = 0
        if self.left == 1:
            self.up = 0
            self.down = 0
        if self.xv == 0 and self.yv == 0:
            self.up = 0
            self.right = 0
            self.left = 0
            self.down = 0
            self.idle = 1
        if self.left == 1:
            # handles changing the sprite for animation
            if self.animiter < 3:

                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catleft1.png")
                )
                self.image = self.image.convert_alpha()
            else:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catleft2.png")
                )
                self.image = self.image.convert_alpha()
                if self.animiter > 4:
                    self.animiter = 0
        if self.right == 1:
            # handles changing the sprite for animation
            if self.animiter < 3:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catright1.png")
                )
                self.image = self.image.convert_alpha()
            else:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catright2.png")
                )
                self.image = self.image.convert_alpha()
                if self.animiter > 4:
                    self.animiter = 0
        if self.up == 1:
            # handles changing the sprite for animation
            if self.animiter < 3:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catup1.png")
                )
                self.image = self.image.convert_alpha()
            else:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catup2.png")
                )
                self.image = self.image.convert_alpha()
                if self.animiter > 4:
                    self.animiter = 0
        if self.down == 1:
            # handles changing the sprite for animation
            if self.animiter < 3:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catwalkdown1.png")
                )
                self.image = self.image.convert_alpha()
            else:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catwalkdown2.png")
                )
                self.image = self.image.convert_alpha()
                if self.animiter > 4:
                    self.animiter = 0
        if self.idle == 1:
            # handles changing the sprite for animation this handles idle animations
            if self.animiter < 150:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catstand1.png")
                )
                self.image = self.image.convert_alpha()
            else:
                self.image = pygame.transform.scale2x(
                    pygame.image. load(f"{self.catprefix}catstand2.png")
                )
                self.image = self.image.convert_alpha()
                if self.animiter > 158:
                    self.animiter = 0


class Poop(pygame.sprite.Sprite):
    # this class makes poop objects
    def __init__(
        self, catx, caty, image="Assets/sprites/poop1.png"
    ):  # initialize poop object
        pygame.sprite.Sprite.__init__(self)
        self.image = pygame.image.load(image)
        self.image = self.image.convert_alpha()
        self.rect = self.image.get_rect()
        self.rect.update((catx + 50), (caty + 50), 32, 32)  # places the poop at the cat
        myengine.allvisible.add(self)
        myengine.poopobj.add(self)
        self.used = 0
        myengine.haspooped = 1

    def update(self):
        if self.used == 1:
            self.kill()


class fish(pygame.sprite.Sprite):
    # this class makes fish objects
    def __init__(self, tempx, tempy):
        pygame.sprite.Sprite.__init__(self)
        self.image = pygame.image.load(
            "Assets/sprites/fish1.png"
        )  # init fish sprite with image
        self.image = self.image.convert_alpha()
        self.rect = self.image.get_rect()  # init fish recct
        self.rect.update(tempx, tempy, 32, 32)  # place fish
        myengine.fishobj.add(self)  # add to group of fish
        myengine.allvisible.add(self)  # add to group of visible

class stopwatch:
    def __init__(self):
        self.starttime = time.time()
        self.pausedtime = 0
        self.paused = 0
    def reset(self):
        self.startime = time.time()
    def update(self):
        if self.paused == 0:
            self.elapsedsec = (time.time() - self.starttime)
            print (f"elapsedsec before math {self.elapsedsec} pausedtime before math {self.pausedtime}")
            self.elapsedsec = self.elapsedsec - self.pausedtime
            print(f"elapsedsec after math {self.elapsedsec} ")
            self.stopwatchmesg = f"time elapsed: {self.elapsedsec:.2f}  seconds"
        elif self.paused == 1:
            self.pausedtime = (time.time() - self.pausestart)
            print(f"myengine.pausedtime {self.pausedtime}")
    def pause(self):
        self.pausestart = time.time()
        self.paused = 1
    def unpause(self):
        self.paused = 0



myengine = Background()
mycat = Player()
cameraobj = Camera()


def main():
    myengine.init_bg_frame()
    myengine.init_score()
    while True:
        myengine.test_keys()
        myengine.update_logic()
        myengine.render_screen()
        myengine.clock.tick(60)
main()
# Out:
# elapsedsec before math 2.86102294921875e-06 pausedtime before math 0
# elapsedsec after math 2.86102294921875e-06
# elapsedsec before math 3.684880018234253 pausedtime before math 0
# elapsedsec after math 3.684880018234253
# elapsedsec before math 3.6899237632751465 pausedtime before math 0
# elapsedsec after math 3.6899237632751465
# elapsedsec before math 3.705660581588745 pausedtime before math 0
# elapsedsec after math 3.705660581588745
# elapsedsec before math 3.7225723266601562 pausedtime before math 0
# elapsedsec after math 3.7225723266601562
# elapsedsec before math 3.7395243644714355 pausedtime before math 0
# elapsedsec after math 3.7395243644714355
# elapsedsec before math 3.75730299949646 pausedtime before math 0
# elapsedsec after math 3.75730299949646
# elapsedsec before math 3.771421432495117 pausedtime before math 0
# elapsedsec after math 3.771421432495117
# elapsedsec before math 3.7867112159729004 pausedtime before math 0
# elapsedsec after math 3.7867112159729004
# elapsedsec before math 3.802726984024048 pausedtime before math 0
# elapsedsec after math 3.802726984024048
# elapsedsec before math 3.819593906402588 pausedtime before math 0
# elapsedsec after math 3.819593906402588
# elapsedsec before math 3.836139678955078 pausedtime before math 0
# elapsedsec after math 3.836139678955078
# elapsedsec before math 3.852212429046631 pausedtime before math 0
# elapsedsec after math 3.852212429046631
# elapsedsec before math 3.8676822185516357 pausedtime before math 0
# elapsedsec after math 3.8676822185516357
# elapsedsec before math 3.883742094039917 pausedtime before math 0
# elapsedsec after math 3.883742094039917
# elapsedsec before math 3.8997232913970947 pausedtime before math 0
# elapsedsec after math 3.8997232913970947
# elapsedsec before math 3.9160571098327637 pausedtime before math 0
# elapsedsec after math 3.9160571098327637
# elapsedsec before math 3.9321746826171875 pausedtime before math 0
# elapsedsec after math 3.9321746826171875
# myengine.pausedtime 4.792213439941406e-05
# myengine.pausedtime 0.046647071838378906
# myengine.pausedtime 0.09598636627197266
# myengine.pausedtime 0.14190220832824707
# myengine.pausedtime 0.1924724578857422
# myengine.pausedtime 0.24064207077026367
# myengine.pausedtime 0.28888702392578125
# myengine.pausedtime 0.33534693717956543
# myengine.pausedtime 0.38175296783447266
# myengine.pausedtime 0.42972731590270996
# myengine.pausedtime 0.4717848300933838
# myengine.pausedtime 0.5134105682373047
# myengine.pausedtime 0.5563559532165527
# myengine.pausedtime 0.5978741645812988
# myengine.pausedtime 0.6473064422607422
# myengine.pausedtime 0.6928887367248535
# myengine.pausedtime 0.7345426082611084
# myengine.pausedtime 0.77569580078125
# myengine.pausedtime 0.8169474601745605
# myengine.pausedtime 0.8585281372070312
# myengine.pausedtime 0.9023852348327637
# myengine.pausedtime 0.9440734386444092
# myengine.pausedtime 0.9859158992767334
# myengine.pausedtime 1.0274584293365479
# myengine.pausedtime 1.069671392440796
# myengine.pausedtime 1.1172881126403809
# myengine.pausedtime 1.1593525409698486
# myengine.pausedtime 1.2006471157073975
# myengine.pausedtime 1.2466866970062256
# myengine.pausedtime 1.2956559658050537
# myengine.pausedtime 1.3385658264160156
# myengine.pausedtime 1.381690263748169
# myengine.pausedtime 1.4232397079467773
# myengine.pausedtime 1.4645471572875977
# myengine.pausedtime 1.5064949989318848
# myengine.pausedtime 1.5521636009216309
# myengine.pausedtime 1.593296766281128
# myengine.pausedtime 1.635084629058838
# elapsedsec before math 5.629125595092773 pausedtime before math 1.635084629058838
# elapsedsec after math 3.9940409660339355
# elapsedsec before math 5.64275336265564 pausedtime before math 1.635084629058838
# elapsedsec after math 4.007668733596802
# elapsedsec before math 5.6586174964904785 pausedtime before math 1.635084629058838
# elapsedsec after math 4.023532867431641
# elapsedsec before math 5.674763917922974 pausedtime before math 1.635084629058838
# elapsedsec after math 4.039679288864136
# elapsedsec before math 5.692015647888184 pausedtime before math 1.635084629058838
# elapsedsec after math 4.056931018829346
# elapsedsec before math 5.707810640335083 pausedtime before math 1.635084629058838
# elapsedsec after math 4.072726011276245
# elapsedsec before math 5.722776889801025 pausedtime before math 1.635084629058838
# elapsedsec after math 4.0876922607421875
# elapsedsec before math 5.740973472595215 pausedtime before math 1.635084629058838
# elapsedsec after math 4.105888843536377
# elapsedsec before math 5.755549907684326 pausedtime before math 1.635084629058838
# elapsedsec after math 4.120465278625488
# elapsedsec before math 5.770843267440796 pausedtime before math 1.635084629058838
# elapsedsec after math 4.135758638381958
# elapsedsec before math 5.787068843841553 pausedtime before math 1.635084629058838
# elapsedsec after math 4.151984214782715
# elapsedsec before math 5.803457975387573 pausedtime before math 1.635084629058838
# elapsedsec after math 4.168373346328735
# elapsedsec before math 5.819574356079102 pausedtime before math 1.635084629058838
# elapsedsec after math 4.184489727020264
# elapsedsec before math 5.836566686630249 pausedtime before math 1.635084629058838
# elapsedsec after math 4.201482057571411
# elapsedsec before math 5.853442668914795 pausedtime before math 1.635084629058838
# elapsedsec after math 4.218358039855957
# elapsedsec before math 5.869608402252197 pausedtime before math 1.635084629058838
# elapsedsec after math 4.234523773193359
# elapsedsec before math 5.885588645935059 pausedtime before math 1.635084629058838
# elapsedsec after math 4.250504016876221
# elapsedsec before math 5.90240216255188 pausedtime before math 1.635084629058838
# elapsedsec after math 4.267317533493042
# elapsedsec before math 5.9185004234313965 pausedtime before math 1.635084629058838
# elapsedsec after math 4.283415794372559
# elapsedsec before math 5.934410095214844 pausedtime before math 1.635084629058838
# elapsedsec after math 4.299325466156006
# elapsedsec before math 5.950271368026733 pausedtime before math 1.635084629058838
# elapsedsec after math 4.3151867389678955
# elapsedsec before math 5.9661619663238525 pausedtime before math 1.635084629058838
# elapsedsec after math 4.331077337265015
# elapsedsec before math 5.981924057006836 pausedtime before math 1.635084629058838
# elapsedsec after math 4.346839427947998
# elapsedsec before math 5.998087644577026 pausedtime before math 1.635084629058838
# elapsedsec after math 4.3630030155181885
# elapsedsec before math 6.014014482498169 pausedtime before math 1.635084629058838
# elapsedsec after math 4.378929853439331
# elapsedsec before math 6.029898166656494 pausedtime before math 1.635084629058838
# elapsedsec after math 4.394813537597656
# elapsedsec before math 6.046087265014648 pausedtime before math 1.635084629058838
# elapsedsec after math 4.4110026359558105
# elapsedsec before math 6.061805963516235 pausedtime before math 1.635084629058838
# elapsedsec after math 4.4267213344573975
# elapsedsec before math 6.07776951789856 pausedtime before math 1.635084629058838
# elapsedsec after math 4.442684888839722
# elapsedsec before math 6.093775033950806 pausedtime before math 1.635084629058838
# elapsedsec after math 4.458690404891968
# elapsedsec before math 6.109883546829224 pausedtime before math 1.635084629058838
# elapsedsec after math 4.474798917770386
# elapsedsec before math 6.12609601020813 pausedtime before math 1.635084629058838
# elapsedsec after math 4.491011381149292
# elapsedsec before math 6.142879486083984 pausedtime before math 1.635084629058838
# elapsedsec after math 4.5077948570251465
# elapsedsec before math 6.158739805221558 pausedtime before math 1.635084629058838
# elapsedsec after math 4.52365517616272
# elapsedsec before math 6.175541877746582 pausedtime before math 1.635084629058838
# elapsedsec after math 4.540457248687744
# elapsedsec before math 6.191404819488525 pausedtime before math 1.635084629058838
# elapsedsec after math 4.5563201904296875
# elapsedsec before math 6.207506895065308 pausedtime before math 1.635084629058838
# elapsedsec after math 4.57242226600647
# elapsedsec before math 6.223605632781982 pausedtime before math 1.635084629058838
# elapsedsec after math 4.5885210037231445
# elapsedsec before math 6.2387168407440186 pausedtime before math 1.635084629058838
# elapsedsec after math 4.603632211685181
# elapsedsec before math 6.255574941635132 pausedtime before math 1.635084629058838
# elapsedsec after math 4.620490312576294
# elapsedsec before math 6.272419214248657 pausedtime before math 1.635084629058838
# elapsedsec after math 4.637334585189819
# elapsedsec before math 6.288526773452759 pausedtime before math 1.635084629058838
# elapsedsec after math 4.653442144393921
# elapsedsec before math 6.303945541381836 pausedtime before math 1.635084629058838
# elapsedsec after math 4.668860912322998
# elapsedsec before math 6.3198606967926025 pausedtime before math 1.635084629058838
# elapsedsec after math 4.684776067733765
# elapsedsec before math 6.336102724075317 pausedtime before math 1.635084629058838
# elapsedsec after math 4.7010180950164795
# elapsedsec before math 6.351975202560425 pausedtime before math 1.635084629058838
# elapsedsec after math 4.716890573501587
# elapsedsec before math 6.367813587188721 pausedtime before math 1.635084629058838
# elapsedsec after math 4.732728958129883
# elapsedsec before math 6.383776903152466 pausedtime before math 1.635084629058838
# elapsedsec after math 4.748692274093628
# elapsedsec before math 6.400081634521484 pausedtime before math 1.635084629058838
# elapsedsec after math 4.7649970054626465
# elapsedsec before math 6.4157915115356445 pausedtime before math 1.635084629058838
# elapsedsec after math 4.780706882476807
# elapsedsec before math 6.431662321090698 pausedtime before math 1.635084629058838
# elapsedsec after math 4.79657769203186
# elapsedsec before math 6.448428630828857 pausedtime before math 1.635084629058838
# elapsedsec after math 4.8133440017700195
# elapsedsec before math 6.4643940925598145 pausedtime before math 1.635084629058838
# elapsedsec after math 4.829309463500977
# elapsedsec before math 6.480378150939941 pausedtime before math 1.635084629058838
# elapsedsec after math 4.8452935218811035
# elapsedsec before math 6.49628472328186 pausedtime before math 1.635084629058838
# elapsedsec after math 4.8612000942230225
# elapsedsec before math 6.51201319694519 pausedtime before math 1.635084629058838
# elapsedsec after math 4.8769285678863525
# elapsedsec before math 6.527643442153931 pausedtime before math 1.635084629058838
# elapsedsec after math 4.892558813095093
# elapsedsec before math 6.544575452804565 pausedtime before math 1.635084629058838
# elapsedsec after math 4.9094908237457275
# elapsedsec before math 6.561455965042114 pausedtime before math 1.635084629058838
# elapsedsec after math 4.926371335983276
# elapsedsec before math 6.577672719955444 pausedtime before math 1.635084629058838
# elapsedsec after math 4.9425880908966064
# elapsedsec before math 6.593496561050415 pausedtime before math 1.635084629058838
# elapsedsec after math 4.958411931991577
# elapsedsec before math 6.609390497207642 pausedtime before math 1.635084629058838
# elapsedsec after math 4.974305868148804
# elapsedsec before math 6.6254191398620605 pausedtime before math 1.635084629058838
# elapsedsec after math 4.990334510803223
# elapsedsec before math 6.641417741775513 pausedtime before math 1.635084629058838
# elapsedsec after math 5.006333112716675
# elapsedsec before math 6.657312393188477 pausedtime before math 1.635084629058838
# elapsedsec after math 5.022227764129639
# elapsedsec before math 6.673234701156616 pausedtime before math 1.635084629058838
# elapsedsec after math 5.038150072097778
# myengine.pausedtime 4.00543212890625e-05
# myengine.pausedtime 0.04509568214416504
# myengine.pausedtime 0.08750629425048828
# myengine.pausedtime 0.13071680068969727
# myengine.pausedtime 0.17265057563781738
# myengine.pausedtime 0.2140514850616455
# myengine.pausedtime 0.2558720111846924
# myengine.pausedtime 0.30222392082214355
# myengine.pausedtime 0.3455488681793213
# myengine.pausedtime 0.3902475833892822
# myengine.pausedtime 0.4328188896179199
# myengine.pausedtime 0.4791104793548584
# myengine.pausedtime 0.5217137336730957
# myengine.pausedtime 0.5635726451873779
# myengine.pausedtime 0.6050527095794678
# myengine.pausedtime 0.6487815380096436
# myengine.pausedtime 0.6907222270965576
# myengine.pausedtime 0.7361574172973633
# myengine.pausedtime 0.7779793739318848
# myengine.pausedtime 0.8200581073760986
# myengine.pausedtime 0.8741185665130615
# myengine.pausedtime 0.9200549125671387
# myengine.pausedtime 0.9621851444244385
# myengine.pausedtime 1.0034880638122559
# myengine.pausedtime 1.0446524620056152
# myengine.pausedtime 1.085850715637207
# myengine.pausedtime 1.128035306930542
# myengine.pausedtime 1.1746890544891357
# myengine.pausedtime 1.2163221836090088
# myengine.pausedtime 1.2575325965881348
# myengine.pausedtime 1.298795461654663
# myengine.pausedtime 1.3407273292541504
# myengine.pausedtime 1.3882453441619873
# myengine.pausedtime 1.4297089576721191
# myengine.pausedtime 1.4704909324645996
# myengine.pausedtime 1.5119550228118896
# myengine.pausedtime 1.5536792278289795
# myengine.pausedtime 1.602797269821167
# myengine.pausedtime 1.6452264785766602
# myengine.pausedtime 1.686556339263916
# myengine.pausedtime 1.7278730869293213
# myengine.pausedtime 1.7696151733398438
# myengine.pausedtime 1.8206768035888672
# myengine.pausedtime 1.866408348083496
# myengine.pausedtime 1.9124796390533447
# myengine.pausedtime 1.957385540008545
# myengine.pausedtime 2.0143213272094727
# myengine.pausedtime 2.0614378452301025
# myengine.pausedtime 2.1180293560028076
# myengine.pausedtime 2.1836323738098145
# myengine.pausedtime 2.227909564971924
# myengine.pausedtime 2.2744407653808594
# myengine.pausedtime 2.315399408340454
# myengine.pausedtime 2.3568928241729736
# myengine.pausedtime 2.4025380611419678
# myengine.pausedtime 2.4464309215545654
# myengine.pausedtime 2.4932448863983154
# myengine.pausedtime 2.5354559421539307
# myengine.pausedtime 2.5785675048828125
# myengine.pausedtime 2.6204729080200195
# myengine.pausedtime 2.6652181148529053
# myengine.pausedtime 2.7105820178985596
# myengine.pausedtime 2.752758741378784
# myengine.pausedtime 2.7945759296417236
# myengine.pausedtime 2.836566209793091
# myengine.pausedtime 2.880182981491089
# myengine.pausedtime 2.9267959594726562
# myengine.pausedtime 2.969637870788574
# myengine.pausedtime 3.0128724575042725
# myengine.pausedtime 3.0555968284606934
# myengine.pausedtime 3.099600315093994
# myengine.pausedtime 3.146451234817505
# myengine.pausedtime 3.1881046295166016
# myengine.pausedtime 3.22955584526062
# myengine.pausedtime 3.2706944942474365
# myengine.pausedtime 3.3123996257781982
# myengine.pausedtime 3.364631175994873
# myengine.pausedtime 3.407823085784912
# myengine.pausedtime 3.449319362640381
# myengine.pausedtime 3.4915640354156494
# myengine.pausedtime 3.544646978378296
# myengine.pausedtime 3.5876147747039795
# myengine.pausedtime 3.6296794414520264
# myengine.pausedtime 3.6718087196350098
# myengine.pausedtime 3.7139506340026855
# myengine.pausedtime 3.756012201309204
# elapsedsec before math 10.495834589004517 pausedtime before math 3.756012201309204
# elapsedsec after math 6.7398223876953125
# elapsedsec before math 10.510545015335083 pausedtime before math 3.756012201309204
# elapsedsec after math 6.754532814025879
# elapsedsec before math 10.526410341262817 pausedtime before math 3.756012201309204
# elapsedsec after math 6.770398139953613
# elapsedsec before math 10.542494535446167 pausedtime before math 3.756012201309204
# elapsedsec after math 6.786482334136963
# elapsedsec before math 10.55889105796814 pausedtime before math 3.756012201309204
# elapsedsec after math 6.8028788566589355
# elapsedsec before math 10.574875354766846 pausedtime before math 3.756012201309204
# elapsedsec after math 6.818863153457642
# elapsedsec before math 10.590886354446411 pausedtime before math 3.756012201309204
# elapsedsec after math 6.834874153137207
# elapsedsec before math 10.60694408416748 pausedtime before math 3.756012201309204
# elapsedsec after math 6.850931882858276
# elapsedsec before math 10.622926235198975 pausedtime before math 3.756012201309204
# elapsedsec after math 6.8669140338897705
# elapsedsec before math 10.640911340713501 pausedtime before math 3.756012201309204
# elapsedsec after math 6.884899139404297
# elapsedsec before math 10.655456304550171 pausedtime before math 3.756012201309204
# elapsedsec after math 6.899444103240967
# elapsedsec before math 10.67119836807251 pausedtime before math 3.756012201309204
# elapsedsec after math 6.915186166763306
# elapsedsec before math 10.6869478225708 pausedtime before math 3.756012201309204
# elapsedsec after math 6.930935621261597
# elapsedsec before math 10.702836513519287 pausedtime before math 3.756012201309204
# elapsedsec after math 6.946824312210083
# elapsedsec before math 10.719064950942993 pausedtime before math 3.756012201309204
# elapsedsec after math 6.963052749633789
# elapsedsec before math 10.735211610794067 pausedtime before math 3.756012201309204
# elapsedsec after math 6.979199409484863
# elapsedsec before math 10.751018047332764 pausedtime before math 3.756012201309204
# elapsedsec after math 6.99500584602356
# elapsedsec before math 10.76678991317749 pausedtime before math 3.756012201309204
# elapsedsec after math 7.010777711868286
# elapsedsec before math 10.782673358917236 pausedtime before math 3.756012201309204
# elapsedsec after math 7.026661157608032
# elapsedsec before math 10.799482583999634 pausedtime before math 3.756012201309204
# elapsedsec after math 7.04347038269043
# elapsedsec before math 10.81533670425415 pausedtime before math 3.756012201309204
# elapsedsec after math 7.059324502944946
# elapsedsec before math 10.831070184707642 pausedtime before math 3.756012201309204
# elapsedsec after math 7.0750579833984375
# elapsedsec before math 10.846869945526123 pausedtime before math 3.756012201309204
# elapsedsec after math 7.090857744216919
# elapsedsec before math 10.862677335739136 pausedtime before math 3.756012201309204
# elapsedsec after math 7.106665134429932
# elapsedsec before math 10.878815412521362 pausedtime before math 3.756012201309204
# elapsedsec after math 7.122803211212158
# elapsedsec before math 10.895604848861694 pausedtime before math 3.756012201309204
# elapsedsec after math 7.13959264755249
# elapsedsec before math 10.912133932113647 pausedtime before math 3.756012201309204
# elapsedsec after math 7.156121730804443
# elapsedsec before math 10.92784595489502 pausedtime before math 3.756012201309204
# elapsedsec after math 7.171833753585815
# elapsedsec before math 10.943931102752686 pausedtime before math 3.756012201309204
# elapsedsec after math 7.1879189014434814
# elapsedsec before math 10.960092306137085 pausedtime before math 3.756012201309204
# elapsedsec after math 7.204080104827881
# elapsedsec before math 10.976483583450317 pausedtime before math 3.756012201309204
# elapsedsec after math 7.220471382141113
# elapsedsec before math 10.99163818359375 pausedtime before math 3.756012201309204
# elapsedsec after math 7.235625982284546
# elapsedsec before math 11.007747411727905 pausedtime before math 3.756012201309204
# elapsedsec after math 7.251735210418701
# elapsedsec before math 11.024189949035645 pausedtime before math 3.756012201309204
# elapsedsec after math 7.26817774772644
# elapsedsec before math 11.040013790130615 pausedtime before math 3.756012201309204
# elapsedsec after math 7.284001588821411
# elapsedsec before math 11.055817365646362 pausedtime before math 3.756012201309204
# elapsedsec after math 7.299805164337158
# elapsedsec before math 11.071882486343384 pausedtime before math 3.756012201309204
# elapsedsec after math 7.31587028503418
# elapsedsec before math 11.088252067565918 pausedtime before math 3.756012201309204
# elapsedsec after math 7.332239866256714
# elapsedsec before math 11.104203939437866 pausedtime before math 3.756012201309204
# elapsedsec after math 7.348191738128662
# elapsedsec before math 11.120476007461548 pausedtime before math 3.756012201309204
# elapsedsec after math 7.364463806152344
# elapsedsec before math 11.136524438858032 pausedtime before math 3.756012201309204
# elapsedsec after math 7.380512237548828
# elapsedsec before math 11.151707649230957 pausedtime before math 3.756012201309204
# elapsedsec after math 7.395695447921753
# elapsedsec before math 11.168538808822632 pausedtime before math 3.756012201309204
# elapsedsec after math 7.412526607513428
# elapsedsec before math 11.18521499633789 pausedtime before math 3.756012201309204
# elapsedsec after math 7.4292027950286865
# elapsedsec before math 11.201053619384766 pausedtime before math 3.756012201309204
# elapsedsec after math 7.4450414180755615
# elapsedsec before math 11.216950416564941 pausedtime before math 3.756012201309204
# elapsedsec after math 7.460938215255737
# elapsedsec before math 11.232935428619385 pausedtime before math 3.756012201309204
# elapsedsec after math 7.476923227310181
# elapsedsec before math 11.248862743377686 pausedtime before math 3.756012201309204
# elapsedsec after math 7.4928505420684814
# elapsedsec before math 11.265199899673462 pausedtime before math 3.756012201309204
# elapsedsec after math 7.509187698364258
# elapsedsec before math 11.280954599380493 pausedtime before math 3.756012201309204
# elapsedsec after math 7.524942398071289
# elapsedsec before math 11.296742677688599 pausedtime before math 3.756012201309204
# elapsedsec after math 7.5407304763793945
# elapsedsec before math 11.31362533569336 pausedtime before math 3.756012201309204
# elapsedsec after math 7.557613134384155
# elapsedsec before math 11.33056354522705 pausedtime before math 3.756012201309204
# elapsedsec after math 7.574551343917847
# elapsedsec before math 11.34739875793457 pausedtime before math 3.756012201309204
# elapsedsec after math 7.591386556625366
# elapsedsec before math 11.36313533782959 pausedtime before math 3.756012201309204
# elapsedsec after math 7.607123136520386
# elapsedsec before math 11.378968238830566 pausedtime before math 3.756012201309204
# elapsedsec after math 7.622956037521362
# elapsedsec before math 11.395049571990967 pausedtime before math 3.756012201309204
# elapsedsec after math 7.639037370681763
# myengine.pausedtime 4.839897155761719e-05
# myengine.pausedtime 0.04175281524658203
# myengine.pausedtime 0.0840756893157959
# myengine.pausedtime 0.13234877586364746
# myengine.pausedtime 0.17357182502746582
# myengine.pausedtime 0.21473264694213867
# myengine.pausedtime 0.2559347152709961
# myengine.pausedtime 0.29755330085754395
# myengine.pausedtime 0.34267282485961914
# myengine.pausedtime 0.3844492435455322
# myengine.pausedtime 0.42575693130493164
# myengine.pausedtime 0.4668734073638916
# myengine.pausedtime 0.5082058906555176
# myengine.pausedtime 0.5553529262542725
# myengine.pausedtime 0.5965662002563477
# myengine.pausedtime 0.6376395225524902
# myengine.pausedtime 0.6835064888000488
# myengine.pausedtime 0.7255501747131348
# myengine.pausedtime 0.7725715637207031
# myengine.pausedtime 0.8146333694458008
# myengine.pausedtime 0.8604543209075928
# myengine.pausedtime 0.9018073081970215
# myengine.pausedtime 0.948143482208252
# myengine.pausedtime 0.9908614158630371
# myengine.pausedtime 1.0317108631134033
# myengine.pausedtime 1.0727641582489014
# myengine.pausedtime 1.114506721496582
# myengine.pausedtime 1.1568405628204346
# myengine.pausedtime 1.2026715278625488
# myengine.pausedtime 1.243530511856079
# myengine.pausedtime 1.2845306396484375
# myengine.pausedtime 1.3256592750549316
# myengine.pausedtime 1.3669049739837646
# myengine.pausedtime 1.412912130355835
# myengine.pausedtime 1.4539668560028076
# myengine.pausedtime 1.4949347972869873
# myengine.pausedtime 1.5361897945404053
# myengine.pausedtime 1.5775973796844482
# myengine.pausedtime 1.624518632888794
# myengine.pausedtime 1.6684556007385254
# myengine.pausedtime 1.709526538848877
# myengine.pausedtime 1.750556230545044
# myengine.pausedtime 1.7943353652954102
# myengine.pausedtime 1.8427777290344238
# myengine.pausedtime 1.8848052024841309
# myengine.pausedtime 1.9277033805847168
# myengine.pausedtime 1.9693145751953125
# myengine.pausedtime 2.011216402053833
# myengine.pausedtime 2.0572850704193115
# myengine.pausedtime 2.1152701377868652
# myengine.pausedtime 2.1608290672302246
# myengine.pausedtime 2.2027487754821777
# myengine.pausedtime 2.25170636177063
# myengine.pausedtime 2.2944047451019287
# myengine.pausedtime 2.3357300758361816
# myengine.pausedtime 2.3785998821258545
# myengine.pausedtime 2.4209673404693604
# myengine.pausedtime 2.4652159214019775
# myengine.pausedtime 2.510528326034546
# myengine.pausedtime 2.552971839904785
# myengine.pausedtime 2.5952250957489014
# myengine.pausedtime 2.6366281509399414
# myengine.pausedtime 2.6806023120880127
# myengine.pausedtime 2.7253918647766113
# myengine.pausedtime 2.7685608863830566
# myengine.pausedtime 2.810497999191284
# myengine.pausedtime 2.8537583351135254
# myengine.pausedtime 2.9051315784454346
# myengine.pausedtime 2.950178384780884
# myengine.pausedtime 2.993043899536133
# myengine.pausedtime 3.0350804328918457
# myengine.pausedtime 3.077298164367676
# myengine.pausedtime 3.120241641998291
# myengine.pausedtime 3.1671977043151855
# myengine.pausedtime 3.2086780071258545
# myengine.pausedtime 3.2503676414489746
# myengine.pausedtime 3.292480945587158
# myengine.pausedtime 3.3349287509918213
# myengine.pausedtime 3.3805935382843018
# myengine.pausedtime 3.4223155975341797
# myengine.pausedtime 3.4639015197753906
# myengine.pausedtime 3.5049633979797363
# myengine.pausedtime 3.547032594680786
# myengine.pausedtime 3.592242479324341
# myengine.pausedtime 3.634648323059082
# myengine.pausedtime 3.6797454357147217
# myengine.pausedtime 3.7214176654815674
# myengine.pausedtime 3.7635908126831055
# myengine.pausedtime 3.818570613861084
# myengine.pausedtime 3.862978219985962
# myengine.pausedtime 3.9091720581054688
# myengine.pausedtime 3.9565985202789307
# myengine.pausedtime 4.003061771392822
# myengine.pausedtime 4.046353101730347
# myengine.pausedtime 4.0891759395599365
# myengine.pausedtime 4.134240388870239
# myengine.pausedtime 4.177459001541138
# myengine.pausedtime 4.21970534324646
# myengine.pausedtime 4.2713782787323
# myengine.pausedtime 4.313315391540527
# myengine.pausedtime 4.354875802993774
# myengine.pausedtime 4.3962013721466064
# myengine.pausedtime 4.438009738922119
# myengine.pausedtime 4.489872694015503
# myengine.pausedtime 4.5310959815979
# myengine.pausedtime 4.57232141494751
# myengine.pausedtime 4.613229990005493
# myengine.pausedtime 4.660003662109375
# myengine.pausedtime 4.710003614425659
# myengine.pausedtime 4.751370668411255
# myengine.pausedtime 4.792728424072266
# myengine.pausedtime 4.833994150161743
# myengine.pausedtime 4.875773668289185
# myengine.pausedtime 4.9211955070495605
# myengine.pausedtime 4.964282274246216
# myengine.pausedtime 5.005388975143433
# myengine.pausedtime 5.046821594238281
# myengine.pausedtime 5.089246511459351
# myengine.pausedtime 5.133896350860596
# myengine.pausedtime 5.176260471343994
# myengine.pausedtime 5.217997312545776
# myengine.pausedtime 5.259131908416748
# myengine.pausedtime 5.301127910614014
# myengine.pausedtime 5.347299814224243
# myengine.pausedtime 5.388828754425049
# myengine.pausedtime 5.430026054382324
# myengine.pausedtime 5.4716527462005615
# myengine.pausedtime 5.513550758361816
# myengine.pausedtime 5.558183908462524
# myengine.pausedtime 5.600289583206177
# myengine.pausedtime 5.6422507762908936
# myengine.pausedtime 5.685105323791504
# myengine.pausedtime 5.726502418518066
# myengine.pausedtime 5.7779271602630615
# myengine.pausedtime 5.820676803588867
# myengine.pausedtime 5.862545967102051
# myengine.pausedtime 5.905022382736206
# myengine.pausedtime 5.953821659088135
# myengine.pausedtime 5.99741268157959
# myengine.pausedtime 6.038405895233154
# myengine.pausedtime 6.079630136489868
# myengine.pausedtime 6.12043833732605
# myengine.pausedtime 6.162440299987793
# myengine.pausedtime 6.214222192764282
# myengine.pausedtime 6.256143093109131
# myengine.pausedtime 6.297574996948242
# myengine.pausedtime 6.339029312133789
# myengine.pausedtime 6.380767345428467
# myengine.pausedtime 6.42572021484375
# myengine.pausedtime 6.467373847961426
# myengine.pausedtime 6.511548280715942
# myengine.pausedtime 6.555008888244629
# myengine.pausedtime 6.59665584564209
# myengine.pausedtime 6.642403602600098
# myengine.pausedtime 6.687775373458862
# myengine.pausedtime 6.728817462921143
# myengine.pausedtime 6.7703680992126465
# myengine.pausedtime 6.812820672988892
# myengine.pausedtime 6.865724802017212
# myengine.pausedtime 6.90770149230957
# myengine.pausedtime 6.949079990386963
# myengine.pausedtime 6.990334510803223
# myengine.pausedtime 7.034983396530151
# myengine.pausedtime 7.079424619674683
# myengine.pausedtime 7.128645181655884
# myengine.pausedtime 7.170288562774658
# myengine.pausedtime 7.215014934539795
# myengine.pausedtime 7.270076274871826
# myengine.pausedtime 7.312989711761475
# myengine.pausedtime 7.354493141174316
# myengine.pausedtime 7.395951509475708
# myengine.pausedtime 7.4395527839660645
# myengine.pausedtime 7.483068466186523
# myengine.pausedtime 7.529906749725342
# myengine.pausedtime 7.572331428527832
# myengine.pausedtime 7.615620374679565
# elapsedsec before math 19.0757896900177 pausedtime before math 7.615620374679565
# elapsedsec after math 11.460169315338135
# elapsedsec before math 19.088963747024536 pausedtime before math 7.615620374679565
# elapsedsec after math 11.47334337234497
# elapsedsec before math 19.105119466781616 pausedtime before math 7.615620374679565
# elapsedsec after math 11.48949909210205
# elapsedsec before math 19.121134519577026 pausedtime before math 7.615620374679565
# elapsedsec after math 11.505514144897461
# elapsedsec before math 19.139782667160034 pausedtime before math 7.615620374679565
# elapsedsec after math 11.524162292480469
# elapsedsec before math 19.15299344062805 pausedtime before math 7.615620374679565
# elapsedsec after math 11.537373065948486
# elapsedsec before math 19.16917586326599 pausedtime before math 7.615620374679565
# elapsedsec after math 11.553555488586426
# elapsedsec before math 19.185627222061157 pausedtime before math 7.615620374679565
# elapsedsec after math 11.570006847381592
# elapsedsec before math 19.202574491500854 pausedtime before math 7.615620374679565
# elapsedsec after math 11.586954116821289
# elapsedsec before math 19.219548225402832 pausedtime before math 7.615620374679565
# elapsedsec after math 11.603927850723267
# elapsedsec before math 19.23546600341797 pausedtime before math 7.615620374679565
# elapsedsec after math 11.619845628738403
# elapsedsec before math 19.251264810562134 pausedtime before math 7.615620374679565
# elapsedsec after math 11.635644435882568
# elapsedsec before math 19.267560243606567 pausedtime before math 7.615620374679565
# elapsedsec after math 11.651939868927002
# elapsedsec before math 19.284717798233032 pausedtime before math 7.615620374679565
# elapsedsec after math 11.669097423553467
# elapsedsec before math 19.30041480064392 pausedtime before math 7.615620374679565
# elapsedsec after math 11.684794425964355
# elapsedsec before math 19.316434144973755 pausedtime before math 7.615620374679565
# elapsedsec after math 11.70081377029419
# elapsedsec before math 19.33167052268982 pausedtime before math 7.615620374679565
# elapsedsec after math 11.716050148010254
# elapsedsec before math 19.3479323387146 pausedtime before math 7.615620374679565
# elapsedsec after math 11.732311964035034
# elapsedsec before math 19.364370822906494 pausedtime before math 7.615620374679565
# elapsedsec after math 11.748750448226929
# elapsedsec before math 19.380568027496338 pausedtime before math 7.615620374679565
# elapsedsec after math 11.764947652816772
# elapsedsec before math 19.396665811538696 pausedtime before math 7.615620374679565
# elapsedsec after math 11.78104543685913
# elapsedsec before math 19.41272783279419 pausedtime before math 7.615620374679565
# elapsedsec after math 11.797107458114624
# elapsedsec before math 19.429216861724854 pausedtime before math 7.615620374679565
# elapsedsec after math 11.813596487045288
# elapsedsec before math 19.445296049118042 pausedtime before math 7.615620374679565
# elapsedsec after math 11.829675674438477
# elapsedsec before math 19.46183204650879 pausedtime before math 7.615620374679565
# elapsedsec after math 11.846211671829224
# elapsedsec before math 19.476886510849 pausedtime before math 7.615620374679565
# elapsedsec after math 11.861266136169434
# elapsedsec before math 19.493257522583008 pausedtime before math 7.615620374679565
# elapsedsec after math 11.877637147903442
# elapsedsec before math 19.509140729904175 pausedtime before math 7.615620374679565
# elapsedsec after math 11.89352035522461
# elapsedsec before math 19.5252103805542 pausedtime before math 7.615620374679565
# elapsedsec after math 11.909590005874634
# elapsedsec before math 19.541207551956177 pausedtime before math 7.615620374679565
# elapsedsec after math 11.925587177276611
# elapsedsec before math 19.557437419891357 pausedtime before math 7.615620374679565
# elapsedsec after math 11.941817045211792
# elapsedsec before math 19.57268524169922 pausedtime before math 7.615620374679565
# elapsedsec after math 11.957064867019653
# elapsedsec before math 19.58893847465515 pausedtime before math 7.615620374679565
# elapsedsec after math 11.973318099975586
# elapsedsec before math 19.604817390441895 pausedtime before math 7.615620374679565
# elapsedsec after math 11.989197015762329
# elapsedsec before math 19.621636390686035 pausedtime before math 7.615620374679565
# elapsedsec after math 12.00601601600647
# elapsedsec before math 19.638893604278564 pausedtime before math 7.615620374679565
# elapsedsec after math 12.023273229598999
# elapsedsec before math 19.654865264892578 pausedtime before math 7.615620374679565
# elapsedsec after math 12.039244890213013
# elapsedsec before math 19.67088770866394 pausedtime before math 7.615620374679565
# elapsedsec after math 12.055267333984375
# elapsedsec before math 19.68673872947693 pausedtime before math 7.615620374679565
# elapsedsec after math 12.071118354797363
# elapsedsec before math 19.70275855064392 pausedtime before math 7.615620374679565
# elapsedsec after math 12.087138175964355
# elapsedsec before math 19.718828439712524 pausedtime before math 7.615620374679565
# elapsedsec after math 12.103208065032959
# elapsedsec before math 19.73474955558777 pausedtime before math 7.615620374679565
# elapsedsec after math 12.119129180908203
# elapsedsec before math 19.750666618347168 pausedtime before math 7.615620374679565
# elapsedsec after math 12.135046243667603
# elapsedsec before math 19.76752471923828 pausedtime before math 7.615620374679565
# elapsedsec after math 12.151904344558716
# elapsedsec before math 19.78343677520752 pausedtime before math 7.615620374679565
# elapsedsec after math 12.167816400527954
# elapsedsec before math 19.79931640625 pausedtime before math 7.615620374679565
# elapsedsec after math 12.183696031570435
# elapsedsec before math 19.815515995025635 pausedtime before math 7.615620374679565
# elapsedsec after math 12.19989562034607
# elapsedsec before math 19.831483125686646 pausedtime before math 7.615620374679565
# elapsedsec after math 12.21586275100708
# elapsedsec before math 19.84740114212036 pausedtime before math 7.615620374679565
# elapsedsec after math 12.231780767440796
# elapsedsec before math 19.863502502441406 pausedtime before math 7.615620374679565
# elapsedsec after math 12.24788212776184
# elapsedsec before math 19.878689527511597 pausedtime before math 7.615620374679565
# elapsedsec after math 12.263069152832031
# elapsedsec before math 19.894848585128784 pausedtime before math 7.615620374679565
# elapsedsec after math 12.279228210449219
# elapsedsec before math 19.911041498184204 pausedtime before math 7.615620374679565
# elapsedsec after math 12.295421123504639
# elapsedsec before math 19.92704677581787 pausedtime before math 7.615620374679565
# elapsedsec after math 12.311426401138306
# elapsedsec before math 19.94310975074768 pausedtime before math 7.615620374679565
# elapsedsec after math 12.327489376068115
# elapsedsec before math 19.959295749664307 pausedtime before math 7.615620374679565
# elapsedsec after math 12.343675374984741
# elapsedsec before math 19.975441932678223 pausedtime before math 7.615620374679565
# elapsedsec after math 12.359821557998657
# elapsedsec before math 19.991677284240723 pausedtime before math 7.615620374679565
# elapsedsec after math 12.376056909561157
# elapsedsec before math 20.00753116607666 pausedtime before math 7.615620374679565
# elapsedsec after math 12.391910791397095
# elapsedsec before math 20.023478507995605 pausedtime before math 7.615620374679565
# elapsedsec after math 12.40785813331604
# elapsedsec before math 20.039260387420654 pausedtime before math 7.615620374679565
# elapsedsec after math 12.423640012741089
# elapsedsec before math 20.05510139465332 pausedtime before math 7.615620374679565
# elapsedsec after math 12.439481019973755
# elapsedsec before math 20.071227550506592 pausedtime before math 7.615620374679565
# elapsedsec after math 12.455607175827026
# elapsedsec before math 20.087076902389526 pausedtime before math 7.615620374679565
# elapsedsec after math 12.471456527709961
# elapsedsec before math 20.103076934814453 pausedtime before math 7.615620374679565
# elapsedsec after math 12.487456560134888
# elapsedsec before math 20.118978261947632 pausedtime before math 7.615620374679565
# elapsedsec after math 12.503357887268066
# elapsedsec before math 20.134726762771606 pausedtime before math 7.615620374679565
# elapsedsec after math 12.519106388092041
# elapsedsec before math 20.151625394821167 pausedtime before math 7.615620374679565
# elapsedsec after math 12.536005020141602
# elapsedsec before math 20.168641328811646 pausedtime before math 7.615620374679565
# elapsedsec after math 12.55302095413208
# elapsedsec before math 20.184414625167847 pausedtime before math 7.615620374679565
# elapsedsec after math 12.568794250488281
# elapsedsec before math 20.200297355651855 pausedtime before math 7.615620374679565
# elapsedsec after math 12.58467698097229
# elapsedsec before math 20.21610450744629 pausedtime before math 7.615620374679565
# elapsedsec after math 12.600484132766724
# elapsedsec before math 20.231889963150024 pausedtime before math 7.615620374679565
# elapsedsec after math 12.616269588470459
# elapsedsec before math 20.24765634536743 pausedtime before math 7.615620374679565
# elapsedsec after math 12.632035970687866
# elapsedsec before math 20.263866901397705 pausedtime before math 7.615620374679565
# elapsedsec after math 12.64824652671814
# elapsedsec before math 20.279841423034668 pausedtime before math 7.615620374679565
# elapsedsec after math 12.664221048355103
# myengine.pausedtime 4.9591064453125e-05
# myengine.pausedtime 0.04195141792297363
# myengine.pausedtime 0.08813285827636719
# myengine.pausedtime 0.13253021240234375
# myengine.pausedtime 0.17402434349060059
# myengine.pausedtime 0.2174060344696045
# myengine.pausedtime 0.25874924659729004
# myengine.pausedtime 0.3001282215118408
# myengine.pausedtime 0.3463423252105713
# elapsedsec before math 20.688231945037842 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.34188961982727
# elapsedsec before math 20.701698064804077 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.355355739593506
# elapsedsec before math 20.718273401260376 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.371931076049805
# elapsedsec before math 20.734429597854614 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.388087272644043
# elapsedsec before math 20.750136852264404 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.403794527053833
# elapsedsec before math 20.765990257263184 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.419647932052612
# elapsedsec before math 20.783897399902344 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.437555074691772
# elapsedsec before math 20.798104286193848 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.451761960983276
# elapsedsec before math 20.814099073410034 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.467756748199463
# elapsedsec before math 20.82995891571045 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.483616590499878
# elapsedsec before math 20.845847845077515 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.499505519866943
# elapsedsec before math 20.86180305480957 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.515460729599
# elapsedsec before math 20.878299236297607 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.531956911087036
# elapsedsec before math 20.894474267959595 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.548131942749023
# elapsedsec before math 20.91022038459778 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.563878059387207
# elapsedsec before math 20.926419258117676 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.580076932907104
# elapsedsec before math 20.94263744354248 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.59629511833191
# elapsedsec before math 20.958829879760742 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.61248755455017
# elapsedsec before math 20.974801540374756 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.628459215164185
# elapsedsec before math 20.99097228050232 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.644629955291748
# elapsedsec before math 21.006828546524048 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.660486221313477
# elapsedsec before math 21.023608207702637 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.677265882492065
# elapsedsec before math 21.040353536605835 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.694011211395264
# elapsedsec before math 21.056147813796997 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.709805488586426
# elapsedsec before math 21.0724618434906 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.72611951828003
# elapsedsec before math 21.08840537071228 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.74206304550171
# elapsedsec before math 21.104365348815918 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.758023023605347
# elapsedsec before math 21.120460748672485 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.774118423461914
# elapsedsec before math 21.136423587799072 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.7900812625885
# elapsedsec before math 21.152501106262207 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.806158781051636
# elapsedsec before math 21.1686053276062 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.82226300239563
# elapsedsec before math 21.18567657470703 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.83933424949646
# elapsedsec before math 21.20258331298828 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.85624098777771
# elapsedsec before math 21.219366788864136 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.873024463653564
# elapsedsec before math 21.235209941864014 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.888867616653442
# elapsedsec before math 21.251254320144653 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.904911994934082
# elapsedsec before math 21.266876697540283 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.920534372329712
# elapsedsec before math 21.282667636871338 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.936325311660767
# elapsedsec before math 21.298885345458984 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.952543020248413
# elapsedsec before math 21.3149836063385 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.96864128112793
# elapsedsec before math 21.331260919570923 pausedtime before math 0.3463423252105713
# elapsedsec after math 20.98491859436035
# elapsedsec before math 21.346662998199463 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.00032067298889
# elapsedsec before math 21.362860441207886 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.016518115997314
# elapsedsec before math 21.37911820411682 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.03277587890625
# elapsedsec before math 21.394994497299194 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.048652172088623
# elapsedsec before math 21.410863399505615 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.064521074295044
# elapsedsec before math 21.427623510360718 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.081281185150146
# elapsedsec before math 21.444841623306274 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.098499298095703
# elapsedsec before math 21.45973038673401 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.113388061523438
# elapsedsec before math 21.475769996643066 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.129427671432495
# elapsedsec before math 21.49180006980896 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.14545774459839
# elapsedsec before math 21.507903337478638 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.161561012268066
# elapsedsec before math 21.523773908615112 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.17743158340454
# elapsedsec before math 21.540568590164185 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.194226264953613
# elapsedsec before math 21.557474374771118 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.211132049560547
# elapsedsec before math 21.573347091674805 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.227004766464233
# elapsedsec before math 21.589183568954468 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.242841243743896
# elapsedsec before math 21.604945182800293 pausedtime before math 0.3463423252105713
# elapsedsec after math 21.25860285758972
# myengine.pausedtime 3.457069396972656e-05
# myengine.pausedtime 0.04108738899230957
# myengine.pausedtime 0.08632922172546387
# myengine.pausedtime 0.12990927696228027
# myengine.pausedtime 0.1709737777709961
# myengine.pausedtime 0.21182727813720703
# myengine.pausedtime 0.25347447395324707
# elapsedsec before math 21.924222707748413 pausedtime before math 0.25347447395324707
# elapsedsec after math 21.670748233795166
# elapsedsec before math 21.93673276901245 pausedtime before math 0.25347447395324707
# elapsedsec after math 21.683258295059204
# elapsedsec before math 21.952681064605713 pausedtime before math 0.25347447395324707
# elapsedsec after math 21.699206590652466
# elapsedsec before math 21.969529151916504 pausedtime before math 0.25347447395324707
# elapsedsec after math 21.716054677963257
# elapsedsec before math 21.98753023147583 pausedtime before math 0.25347447395324707
# elapsedsec after math 21.734055757522583
# elapsedsec before math 22.0007061958313 pausedtime before math 0.25347447395324707
# elapsedsec after math 21.74723172187805
# elapsedsec before math 22.01760768890381 pausedtime before math 0.25347447395324707
# elapsedsec after math 21.76413321495056
# elapsedsec before math 22.03448462486267 pausedtime before math 0.25347447395324707
# elapsedsec after math 21.781010150909424
# elapsedsec before math 22.05036449432373 pausedtime before math 0.25347447395324707
# elapsedsec after math 21.796890020370483
# elapsedsec before math 22.066447496414185 pausedtime before math 0.25347447395324707
# elapsedsec after math 21.812973022460938
# elapsedsec before math 22.082313299179077 pausedtime before math 0.25347447395324707
# elapsedsec after math 21.82883882522583
# myengine.pausedtime 2.6941299438476562e-05
# myengine.pausedtime 0.0445556640625
# myengine.pausedtime 0.08736467361450195
# myengine.pausedtime 0.13035035133361816
# myengine.pausedtime 0.17346835136413574
# elapsedsec before math 22.328030347824097 pausedtime before math 0.17346835136413574
# elapsedsec after math 22.15456199645996
# elapsedsec before math 22.34136939048767 pausedtime before math 0.17346835136413574
# elapsedsec after math 22.167901039123535
# ...
# elapsedsec before math 30.164714336395264 pausedtime before math 0.17715024948120117
# elapsedsec after math 29.987564086914062
# elapsedsec before math 30.18159770965576 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.00444746017456
# elapsedsec before math 30.19758677482605 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.02043652534485
# elapsedsec before math 30.21292805671692 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.035777807235718
# elapsedsec before math 30.229250192642212 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.05209994316101
# elapsedsec before math 30.245546340942383 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.06839609146118
# elapsedsec before math 30.261581420898438 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.084431171417236
# elapsedsec before math 30.27794885635376 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.10079860687256
# elapsedsec before math 30.293076515197754 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.115926265716553
# elapsedsec before math 30.309104919433594 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.131954669952393
# elapsedsec before math 30.325132369995117 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.147982120513916
# elapsedsec before math 30.341167449951172 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.16401720046997
# elapsedsec before math 30.3572838306427 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.1801335811615
# elapsedsec before math 30.37322235107422 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.196072101593018
# elapsedsec before math 30.389217138290405 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.212066888809204
# elapsedsec before math 30.40510845184326 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.22795820236206
# elapsedsec before math 30.42108726501465 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.243937015533447
# elapsedsec before math 30.437026977539062 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.25987672805786
# elapsedsec before math 30.453242540359497 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.276092290878296
# elapsedsec before math 30.469091653823853 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.29194140434265
# elapsedsec before math 30.48532509803772 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.30817484855652
# elapsedsec before math 30.501248121261597 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.324097871780396
# elapsedsec before math 30.517455577850342 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.34030532836914
# elapsedsec before math 30.532661199569702 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.3555109500885
# elapsedsec before math 30.548948526382446 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.371798276901245
# elapsedsec before math 30.56510019302368 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.38794994354248
# elapsedsec before math 30.58128786087036 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.40413761138916
# elapsedsec before math 30.597222566604614 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.420072317123413
# elapsedsec before math 30.61315894126892 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.43600869178772
# elapsedsec before math 30.629459381103516 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.452309131622314
# elapsedsec before math 30.64566659927368 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.46851634979248
# elapsedsec before math 30.661967992782593 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.48481774330139
# elapsedsec before math 30.67787218093872 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.50072193145752
# elapsedsec before math 30.693870544433594 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.516720294952393
# elapsedsec before math 30.709883213043213 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.53273296356201
# elapsedsec before math 30.72608208656311 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.54893183708191
# elapsedsec before math 30.742218255996704 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.565068006515503
# elapsedsec before math 30.758301496505737 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.581151247024536
# elapsedsec before math 30.774425506591797 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.597275257110596
# elapsedsec before math 30.789840698242188 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.612690448760986
# elapsedsec before math 30.806154489517212 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.62900424003601
# elapsedsec before math 30.822158813476562 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.64500856399536
# elapsedsec before math 30.838239192962646 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.661088943481445
# elapsedsec before math 30.854382514953613 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.677232265472412
# elapsedsec before math 30.87029194831848 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.69314169883728
# elapsedsec before math 30.88641119003296 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.709260940551758
# elapsedsec before math 30.90263295173645 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.72548270225525
# elapsedsec before math 30.919118404388428 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.741968154907227
# elapsedsec before math 30.934792518615723 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.75764226913452
# elapsedsec before math 30.95124316215515 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.77409291267395
# elapsedsec before math 30.96685028076172 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.789700031280518
# elapsedsec before math 30.983994007110596 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.806843757629395
# elapsedsec before math 31.000301122665405 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.823150873184204
# elapsedsec before math 31.015867471694946 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.838717222213745
# elapsedsec before math 31.031782865524292 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.85463261604309
# elapsedsec before math 31.047751426696777 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.870601177215576
# elapsedsec before math 31.06376051902771 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.88661026954651
# elapsedsec before math 31.080604076385498 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.903453826904297
# elapsedsec before math 31.09648323059082 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.91933298110962
# elapsedsec before math 31.11244297027588 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.935292720794678
# elapsedsec before math 31.128486394882202 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.951336145401
# elapsedsec before math 31.144208669662476 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.967058420181274
# elapsedsec before math 31.16028618812561 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.98313593864441
# elapsedsec before math 31.17599630355835 pausedtime before math 0.17715024948120117
# elapsedsec after math 30.99884605407715
# elapsedsec before math 31.192018270492554 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.014868021011353
# elapsedsec before math 31.20818305015564 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.03103280067444
# elapsedsec before math 31.2241792678833 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.0470290184021
# elapsedsec before math 31.24011993408203 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.06296968460083
# elapsedsec before math 31.255979776382446 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.078829526901245
# elapsedsec before math 31.272197008132935 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.095046758651733
# elapsedsec before math 31.28816819190979 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.11101794242859
# elapsedsec before math 31.304096937179565 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.126946687698364
# elapsedsec before math 31.32026767730713 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.143117427825928
# elapsedsec before math 31.33643412590027 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.159283876419067
# elapsedsec before math 31.352667093276978 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.175516843795776
# elapsedsec before math 31.369425058364868 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.192274808883667
# elapsedsec before math 31.385424613952637 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.208274364471436
# elapsedsec before math 31.401395797729492 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.22424554824829
# elapsedsec before math 31.416736364364624 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.239586114883423
# elapsedsec before math 31.43322777748108 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.256077527999878
# elapsedsec before math 31.448843479156494 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.271693229675293
# elapsedsec before math 31.465187549591064 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.288037300109863
# elapsedsec before math 31.481321811676025 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.304171562194824
# elapsedsec before math 31.497502088546753 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.32035183906555
# elapsedsec before math 31.513204097747803 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.3360538482666
# elapsedsec before math 31.529159784317017 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.352009534835815
# elapsedsec before math 31.54507827758789 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.36792802810669
# elapsedsec before math 31.561007976531982 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.38385772705078
# elapsedsec before math 31.576889514923096 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.399739265441895
# elapsedsec before math 31.592926502227783 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.415776252746582
# elapsedsec before math 31.608968019485474 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.431817770004272
# elapsedsec before math 31.625022172927856 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.447871923446655
# elapsedsec before math 31.641001224517822 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.46385097503662
# elapsedsec before math 31.65686297416687 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.47971272468567
# elapsedsec before math 31.672987699508667 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.495837450027466
# elapsedsec before math 31.689175128936768 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.512024879455566
# elapsedsec before math 31.705461978912354 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.528311729431152
# elapsedsec before math 31.721374034881592 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.54422378540039
# elapsedsec before math 31.73723816871643 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.56008791923523
# elapsedsec before math 31.75335693359375 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.57620668411255
# elapsedsec before math 31.76912569999695 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.591975450515747
# elapsedsec before math 31.784761667251587 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.607611417770386
# elapsedsec before math 31.801101207733154 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.623950958251953
# elapsedsec before math 31.817466497421265 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.640316247940063
# elapsedsec before math 31.833633422851562 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.65648317337036
# elapsedsec before math 31.850593328475952 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.67344307899475
# elapsedsec before math 31.86780881881714 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.690658569335938
# elapsedsec before math 31.882821083068848 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.705670833587646
# elapsedsec before math 31.898712396621704 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.721562147140503
# elapsedsec before math 31.915611267089844 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.738461017608643
# elapsedsec before math 31.932512283325195 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.755362033843994
# elapsedsec before math 31.94847559928894 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.77132534980774
# elapsedsec before math 31.964449167251587 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.787298917770386
# elapsedsec before math 31.980510473251343 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.80336022377014
# elapsedsec before math 31.996264457702637 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.819114208221436
# elapsedsec before math 32.01230001449585 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.83514976501465
# elapsedsec before math 32.028401374816895 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.851251125335693
# elapsedsec before math 32.044615268707275 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.867465019226074
# elapsedsec before math 32.06049036979675 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.88334012031555
# elapsedsec before math 32.11079216003418 pausedtime before math 0.17715024948120117
# elapsedsec after math 31.93364191055298
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 871
#     869         myengine.render_screen()
#     870         myengine.clock.tick(60)
# --> 871 main()
#
# Cell In[2], line 869, in main()
#     867 myengine.test_keys()
#     868 myengine.update_logic()
# --> 869 myengine.render_screen()
#     870 myengine.clock.tick(60)
#
# Cell In[2], line 93, in Engine.render_screen(self)
#      88 elif self.mode == 3:
#      89
#      90     #game running
#      91     for sprite in self.allvisible:
# ---> 93         self.screen.blit(
#      94             sprite.image,
#      95             (sprite.rect.x - cameraobj.rect.x, sprite.rect.y - cameraobj.rect.y),
#      96         )
#      98     self.render_hud()
#      99 elif self.mode == 4:
#
# error: display Surface quit
